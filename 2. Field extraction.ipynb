# %% [markdown]
# # 2. Field extraction using Azure Content Understanding
#
# <img src="https://learn.microsoft.com/en-us/azure/ai-services/content-understanding/media/overview/content-understanding-framework-2025.png#lightbox">
#
# Azure Content Understanding in Foundry Tools is an Foundry Tool that's available as part of the Microsoft Foundry Resource in the Azure portal. It uses generative AI to process/ingest content of many types (documents, images, videos, and audio) into a user-defined output format. Content Understanding offers a streamlined process to reason over large amounts of unstructured data, accelerating time-to-value by generating an output that can be integrated into automation and analytical workflows.
#
# Content Understanding is now a Generally Available (GA) service with the release of the 2025-11-01 API version. It's now available in a broader range of regions.
#
# ### Core Documentation
# 1. **[What is Azure Content Understanding in Foundry Tools?](https://learn.microsoft.com/en-us/azure/ai-services/content-understanding/overview)** - Main overview page
# 2. **[FAQ - Frequently Asked Questions](https://learn.microsoft.com/en-us/azure/ai-services/content-understanding/faq)** - Common questions and answers
# 3. **[Choosing the Right Tool: Document Intelligence vs Content Understanding](https://learn.microsoft.com/en-us/azure/ai-services/content-understanding/choosing-right-ai-tool)** - Comparison guide
# 4. **[Models and Deployments](https://learn.microsoft.com/en-us/azure/ai-services/content-understanding/concepts/models-deployments)** - Supported models configuration
# 5. **[Pricing Explainer](https://learn.microsoft.com/en-us/azure/ai-services/content-understanding/pricing-explainer)** - Pricing details and optimization
#
# ### Modality-Specific Documentation
# 6. **[Document Processing Overview](https://learn.microsoft.com/en-us/azure/ai-services/content-understanding/document/overview)** - Field extraction and grounding
# 7. **[Video Solutions (Preview)](https://learn.microsoft.com/en-us/azure/ai-services/content-understanding/video/overview)** - Video analysis capabilities
# 8. **[Image Solutions (Preview)](https://learn.microsoft.com/en-us/azure/ai-services/content-understanding/image/overview)** - Image extraction and analysis
# 9. **[Face Solutions (Preview)](https://learn.microsoft.com/en-us/azure/ai-services/content-understanding/face/overview)** - Face detection and recognition
#
# ### Additional Resources
# 10. **[Transparency Note](https://learn.microsoft.com/en-us/azure/ai-foundry/responsible-ai/content-understanding/transparency-note)** - Responsible AI information
# 11. **[Code Samples on GitHub](https://github.com/Azure-Samples/azure-ai-content-understanding-python)** - Python implementation examples
# 12. **[Azure Content Understanding Pricing](https://azure.microsoft.com/pricing/details/content-understanding/)** - Official pricing page

# %% [markdown]
# ## Using Prebuilt Analyzers (Recommended Starting Point)
#
# Azure AI Content Understanding provides **70+ production-ready prebuilt analyzers** that cover common scenarios across finance, healthcare, legal, tax, and business domains. These analyzers are:
#
# - **Immediately Available** - No training, configuration, or customization needed
# - **Battle-Tested** - Built on rich knowledge bases of thousands of real-world document examples
# - **Continuously Improved** - Regularly updated by Microsoft to handle document variations
# - **Cost-Effective** - Save development time and resources by using proven solutions
# - **Comprehensive Coverage** - Extensive support for Financial documents (invoices, receipts, bank statements, credit cards), Identity documents (passports, driver licenses, ID cards, health insurance), Tax documents (40+ US tax forms including 1040, W-2, 1099 variants), Mortgage documents (applications, appraisals, disclosures), Business documents (contracts, purchase orders, procurement), and many more specialized scenarios
#
# > **Best Practice**: Always explore prebuilt analyzers first. Build custom analyzers only when prebuilt options don't meet your specific requirements.
#
# ### Complete List of Prebuilt Analyzer Categories
#
# **Content Extraction & RAG**
# - `prebuilt-read`, `prebuilt-layout` - OCR and layout analysis
# - `prebuilt-documentSearch`, `prebuilt-imageSearch`, `prebuilt-audioSearch`, `prebuilt-videoSearch` - RAG-optimized
#
# **Financial Documents**
# - `prebuilt-invoice`, `prebuilt-receipt`, `prebuilt-creditCard`, `prebuilt-bankStatement.us`, `prebuilt-check.us`, `prebuilt-creditMemo`
#
# **Identity & Healthcare**
# - `prebuilt-idDocument`, `prebuilt-idDocument.passport`, `prebuilt-healthInsuranceCard.us`
#
# **Tax Documents (US)**
# - 40+ tax form analyzers including `prebuilt-tax.us.1040`, `prebuilt-tax.us.w2`, all 1099 variants, 1098 series, and more
#
# **Mortgage Documents (US)**
# - `prebuilt-mortgage.us.1003`, `prebuilt-mortgage.us.1004`, `prebuilt-mortgage.us.1005`, `prebuilt-mortgage.us.closingDisclosure`
#
# **Legal & Business**
# - `prebuilt-contract`, `prebuilt-procurement`, `prebuilt-purchaseOrder`, `prebuilt-marriageCertificate.us`
#
# **Other Specialized**
# - `prebuilt-utilityBill`, `prebuilt-payStub.us`, and more
#
# > **Learn More**: [Complete Prebuilt Analyzers Documentation](https://learn.microsoft.com/en-us/azure/ai-services/content-understanding/concepts/prebuilt-analyzers)

# %%
import json
import os
import sys

from azure.identity import DefaultAzureCredential
from datetime import datetime
from dotenv import load_dotenv
from helper.content_understanding_client import AzureContentUnderstandingClient
from helper.document_processor import DocumentProcessor
from helper.sample_helper import save_json_to_file 
from IPython.display import display, Markdown
from PIL import Image
from typing import Dict, Any

# %%
sys.version
# Out:
# '3.10.18 (main, Jun  5 2025, 13:14:17) [GCC 11.2.0]'

# %%
print(f"Today is {datetime.today().strftime('%d-%b-%Y %H:%M:%S')}")
# Out:
# Today is 11-Feb-2026 13:30:42

# %% [markdown]
# ## 1. Azure Content Understanding client

# %%
load_dotenv("azure.env")

AZURE_AI_ENDPOINT = os.getenv("AZURE_AI_ENDPOINT")
API_VERSION = "2025-11-01"  # Subject to change. Check the documentation
GPT_4_1_DEPLOYMENT = "gpt-4.1"  # Name of the model deployed in Microsoft Foundry
GPT_4_1_MINI_DEPLOYMENT = "gpt-4.1-mini"  # Name of the model deployed in Microsoft Foundry
TEXT_EMBEDDING_3_LARGE_DEPLOYMENT = "text-embedding-3-large"  # Name of the model deployed in Microsoft Foundry

# %%
def token_provider():
    """Provides fresh Azure Cognitive Services tokens."""
    try:
        credential = DefaultAzureCredential()
        token = credential.get_token(
            "https://cognitiveservices.azure.com/.default")
        return token.token
    except Exception as e:
        print(f"❌ Token acquisition failed: {e}")
        raise


try:
    if not AZURE_AI_ENDPOINT or not API_VERSION:
        raise ValueError("AZURE_AI_ENDPOINT and API_VERSION must be set")

    print("Initializing Azure Content Understanding Client...")
    client = AzureContentUnderstandingClient(
        endpoint=AZURE_AI_ENDPOINT,
        api_version=API_VERSION,
        token_provider=token_provider,
        x_ms_useragent="azure-ai-content-understanding-python-sample-ga"
    )
    print("✅ Done")

except ValueError as e:
    print(f"❌ Configuration error: {e}")
    raise
except Exception as e:
    print(f"❌ Client creation failed: {e}")
    raise
# Out:
# Initializing Azure Content Understanding Client...
# ✅ Done

# %%
missing_deployments = []

if not GPT_4_1_DEPLOYMENT:
    missing_deployments.append("GPT_4_1_DEPLOYMENT")
if not GPT_4_1_MINI_DEPLOYMENT:
    missing_deployments.append("GPT_4_1_MINI_DEPLOYMENT")
if not TEXT_EMBEDDING_3_LARGE_DEPLOYMENT:
    missing_deployments.append("TEXT_EMBEDDING_3_LARGE_DEPLOYMENT")

if missing_deployments:
    print(f"❌ Warning: Missing required model deployment configuration(s):")
    for deployment in missing_deployments:
        print(f"   - {deployment}")
    print(
        "\n   Prebuilt analyzers require GPT-4.1, GPT-4.1-mini, and text-embedding-3-large deployments."
    )
    print("   Please:")
    print("   1. Deploy all three models in Azure AI Foundry")
    print("   2. Add the following to notebooks/.env:")
    print("      GPT_4_1_DEPLOYMENT=<your-gpt-4.1-deployment-name>")
    print("      GPT_4_1_MINI_DEPLOYMENT=<your-gpt-4.1-mini-deployment-name>")
    print(
        "      TEXT_EMBEDDING_3_LARGE_DEPLOYMENT=<your-text-embedding-3-large-deployment-name>"
    )
    print("   3. Restart the kernel and run this cell again")

else:
    print(f"📋 Configuring default model deployments...")
    print(f"   GPT-4.1 deployment: {GPT_4_1_DEPLOYMENT}")
    print(f"   GPT-4.1-mini deployment: {GPT_4_1_MINI_DEPLOYMENT}")
    print(
        f"   text-embedding-3-large deployment: {TEXT_EMBEDDING_3_LARGE_DEPLOYMENT}"
    )
    try:
        result = client.update_defaults({
            "gpt-4.1":
            GPT_4_1_DEPLOYMENT,
            "gpt-4.1-mini":
            GPT_4_1_MINI_DEPLOYMENT,
            "text-embedding-3-large":
            TEXT_EMBEDDING_3_LARGE_DEPLOYMENT
        })
        print(f"\n✅ Default model deployments configured successfully")
        print(f"   Model mappings:")
        for model, deployment in result.get("modelDeployments", {}).items():
            print(f"     {model} → {deployment}")
    except Exception as e:
        print(f"❌ Failed to configure defaults: {e}")
        print(f"   This may happen if:")
        print(
            f"   - One or more deployment names don't exist in your Azure AI Foundry project"
        )
        print(f"   - You don't have permission to update defaults")
        raise
# Out:
# 📋 Configuring default model deployments...
#    GPT-4.1 deployment: gpt-4.1
#    GPT-4.1-mini deployment: gpt-4.1-mini
#    text-embedding-3-large deployment: text-embedding-3-large
#
# ✅ Default model deployments configured successfully
#    Model mappings:
#      gpt-4.1 → gpt-4.1
#      gpt-4.1-mini → gpt-4.1-mini
#      text-embedding-3-large → text-embedding-3-large

# %%
try:
    defaults = client.get_defaults()
    print(f"✅ Retrieved default settings")

    model_deployments = defaults.get("modelDeployments", {})

    if model_deployments:
        print(f"\n✅ Model Deployments:")
        for model_name, deployment_name in model_deployments.items():
            print(f"   {model_name}: {deployment_name}")
    else:
        print("❌ No model deployments configured")

except Exception as e:
    print(f"❌  Error retrieving defaults: {e}")
    print("This is expected if no defaults have been configured yet.")
# Out:
# ✅ Retrieved default settings
#
# ✅ Model Deployments:
#    gpt-4.1: gpt-4.1
#    gpt-4.1-mini: gpt-4.1-mini
#    text-embedding-3-large: text-embedding-3-large

# %% [markdown]
# ## 2. Document OCR using `prebuilt-document`

# %%
DOCS_DIR = "documents"

# %%
document_file = os.path.join(DOCS_DIR, "contoso.pdf")
# !ls $document_file -lh
# Out:
# -rwxrwxrwx 1 root root 533K Dec  2 09:22 documents/contoso.pdf

# %%
analyzer_id = "prebuilt-document"

print(f"🔍 Analyzing '{document_file}' with '{analyzer_id}'...")

response = client.begin_analyze_binary(
    analyzer_id=analyzer_id,
    file_location=document_file,
)

print(f"⏳ Please wait...")
analysis_result = client.poll_result(response)
print(f"✅ Done")
# Out:
# 🔍 Analyzing 'documents/contoso.pdf' with 'prebuilt-document'...
# ⏳ Please wait...
# ✅ Done

# %%
print("\033[1;31;34m")
print(json.dumps(analysis_result, indent=5))
# Out:
# {
#      "id": "6c640dde-fc0b-4302-9d69-7220787bb75b",
#      "status": "Succeeded",
#      "result": {
#           "analyzerId": "prebuilt-document",
#           "apiVersion": "2025-11-01",
#           "createdAt": "2026-02-11T13:30:44Z",
#           "stringEncoding": "codePoint",
#           "warnings": [],
#           "contents": [
#                {
#                     "path": "input1",
#                     "markdown": "# Contoso Electronics Plan and Benefit Packages\n\n\n![Contoso Electronics](figures/1.1)\n\n\n<!-- PageBreak -->\n\nThis document contains information generated using a language model (Azure OpenAI). The information\ncontained in this document is only for demonstration purposes and does not reflect the opinions or\nbeliefs of Microsoft. Microsoft makes no representations or warranties of any kind, express or implied,\nabout the completeness, accuracy, reliability, suitability or availability with respect to the information\ncontained in this document.\n\nAll rights reserved to Microsoft\n\n<!-- PageBreak -->\n\nWelcome to Contoso Electronics! We are excited to offer our employees two comprehensive health\ninsurance plans through Northwind Health.\n\n\n## Northwind Health Plus\n\nNorthwind Health Plus is a comprehensive plan that provides comprehensive coverage for medical,\nvision, and dental services. This plan also offers prescription drug coverage, mental health and substance\nabuse coverage, and coverage for preventive care services. With Northwind Health Plus, you can choose\nfrom a variety of in-network providers, including primary care physicians, specialists, hospitals, and\npharmacies. This plan also offers coverage for emergency services, both in-network and out-of-network.\n\n\n## Northwind Standard\n\nNorthwind Standard is a basic plan that provides coverage for medical, vision, and dental services. This\nplan also offers coverage for preventive care services, as well as prescription drug coverage. With\nNorthwind Standard, you can choose from a variety of in-network providers, including primary care\nphysicians, specialists, hospitals, and pharmacies. This plan does not offer coverage for emergency\nservices, mental health and substance abuse coverage, or out-of-network services.\n\n\n## Comparison of Plans\n\nBoth plans offer coverage for routine physicals, well-child visits, immunizations, and other preventive\ncare services. The plans also cover preventive care services such as mammograms, colonoscopies, and\nother cancer screenings.\n\nNorthwind Health Plus offers more comprehensive coverage than Northwind Standard. This plan offers\ncoverage for emergency services, both in-network and out-of-network, as well as mental health and\nsubstance abuse coverage. Northwind Standard does not offer coverage for emergency services, mental\nhealth and substance abuse coverage, or out-of-network services.\n\nBoth plans offer coverage for prescription drugs. Northwind Health Plus offers a wider range of\nprescription drug coverage than Northwind Standard. Northwind Health Plus covers generic, brand-\nname, and specialty drugs, while Northwind Standard only covers generic and brand-name drugs.\n\nBoth plans offer coverage for vision and dental services. Northwind Health Plus offers coverage for vision\nexams, glasses, and contact lenses, as well as dental exams, cleanings, and fillings. Northwind Standard\nonly offers coverage for vision exams and glasses.\n\nBoth plans offer coverage for medical services. Northwind Health Plus offers coverage for hospital stays,\ndoctor visits, lab tests, and X-rays. Northwind Standard only offers coverage for doctor visits and lab\ntests.\n\nNorthwind Health Plus is a comprehensive plan that offers more coverage than Northwind Standard.\nNorthwind Health Plus offers coverage for emergency services, mental health and substance abuse\ncoverage, and out-of-network services, while Northwind Standard does not. Northwind Health Plus also\n\n<!-- PageBreak -->\n\noffers a wider range of prescription drug coverage than Northwind Standard. Both plans offer coverage\nfor vision and dental services, as well as medical services.\n\n\n## Cost Comparison\n\nContoso Electronics deducts the employee's portion of the healthcare cost from each paycheck. This\nmeans that the cost of the health insurance will be spread out over the course of the year, rather\nthan being paid  ...
#                     "kind": "document",
#                     "startPageNumber": 1,
#                     "endPageNumber": 4,
#                     "unit": "inch",
#                     "pages": [
#                          {
#                               "pageNumber": 1,
#                               "angle": 0.02698024,
#                               "width": 8.5,
#                               "height": 11
#                          },
#                          {
#                               "pageNumber": 2,
#                               "angle": 0,
#                               "width": 8.5,
#                               "height": 11
#                          },
#                          {
#                               "pageNumber": 3,
#                               "angle": 0,
#                               "width": 8.5,
#                               "height": 11
#                          },
#                          {
#                               "pageNumber": 4,
#                               "angle": 0,
#                               "width": 8.5,
#                               "height": 11
#                          }
#                     ],
#                     "analyzerId": "prebuilt-document",
#                     "mimeType": "application/pdf"
#                }
#           ]
#      },
#      "usage": {
#           "documentPagesStandard": 4
#      }
# }

# %%
display(Markdown(analysis_result['result']['contents'][0]['markdown']))
# Out:
# # Contoso Electronics Plan and Benefit Packages
#
#
# ![Contoso Electronics](figures/1.1)
#
#
# <!-- PageBreak -->
#
# This document contains information generated using a language model (Azure OpenAI). The information
# contained in this document is only for demonstration purposes and does not reflect the opinions or
# beliefs of Microsoft. Microsoft makes no representations or warranties of any kind, express or implied,
# about the completeness, accuracy, reliability, suitability or availability with respect to the information
# contained in this document.
#
# All rights reserved to Microsoft
#
# <!-- PageBreak -->
#
# Welcome to Contoso Electronics! We are excited to offer our employees two comprehensive health
# insurance plans through Northwind Health.
#
#
# ## Northwind Health Plus
#
# Northwind Health Plus is a comprehensive plan that provides comprehensive coverage for medical,
# vision, and dental services. This plan also offers prescription drug coverage, mental health and substance
# abuse coverage, and coverage for preventive care services. With Northwind Health Plus, you can choose
# from a variety of in-network providers, including primary care physicians, specialists, hospitals, and
# pharmacies. This plan also offers coverage for emergency services, both in-network and out-of-network.
#
#
# ## Northwind Standard
#
# Northwind Standard is a basic plan that provides coverage for medical, vision, and dental services. This
# plan also offers coverage for preventive care services, as well as prescription drug coverage. With
# Northwind Standard, you can choose from a variety of in-network providers, including primary care
# physicians, specialists, hospitals, and pharmacies. This plan does not offer coverage for emergency
# services, mental health and substance abuse coverage, or out-of-network services.
#
#
# ## Comparison of Plans
#
# Both plans offer coverage for routine physicals, well-child visits, immunizations, and other preventive
# care services. The plans also cover preventive care services such as mammograms, colonoscopies, and
# other cancer screenings.
#
# Northwind Health Plus offers more comprehensive coverage than Northwind Standard. This plan offers
# coverage for emergency services, both in-network and out-of-network, as well as mental health and
# substance abuse coverage. Northwind Standard does not offer coverage for emergency services, mental
# health and substance abuse coverage, or out-of-network services.
#
# Both plans offer coverage for prescription drugs. Northwind Health Plus offers a wider range of
# prescription drug coverage than Northwind Standard. Northwind Health Plus covers generic, brand-
# name, and specialty drugs, while Northwind Standard only covers generic and brand-name drugs.
#
# Both plans offer coverage for vision and dental services. Northwind Health Plus offers coverage for vision
# exams, glasses, and contact lenses, as well as dental exams, cleanings, and fillings. Northwind Standard
# only offers coverage for vision exams and glasses.
#
# Both plans offer coverage for medical services. Northwind Health Plus offers coverage for hospital stays,
# doctor visits, lab tests, and X-rays. Northwind Standard only offers coverage for doctor visits and lab
# tests.
#
# Northwind Health Plus is a comprehensive plan that offers more coverage than Northwind Standard.
# Northwind Health Plus offers coverage for emergency services, mental health and substance abuse
# coverage, and out-of-network services, while Northwind Standard does not. Northwind Health Plus also
#
# <!-- PageBreak -->
#
# offers a wider range of prescription drug coverage than Northwind Standard. Both plans offer coverage
# for vision and dental services, as well as medical services.
#
#
# ## Cost Comparison
#
# Contoso Electronics deducts the employee's portion of the healthcare cost from each paycheck. This
# means that the cost of the health insurance will be spread out over the course of the year, rather
# than being paid in one lump sum. The employee's portion of the cost will be calculated based on the
# selected health plan and the number of people covered by the insurance. The table below shows a
# cost comparison between the different health plans offered by Contoso Electronics:
#
#
# <table>
# <tr>
# <th colspan="3">Employee's cost per paycheck</th>
# </tr>
# <tr>
# <th></th>
# <th>Northwind Standard</th>
# <th>Northwind Health Plus</th>
# </tr>
# <tr>
# <th>Employee Only</th>
# <th>$45.00</th>
# <th>$55.00</th>
# </tr>
# <tr>
# <th>Employee +1</th>
# <th>$65.00</th>
# <th>$71.00</th>
# </tr>
# <tr>
# <th>Employee +2 or more</th>
# <th>$78.00</th>
# <th>$89.00</th>
# </tr>
# </table>
#
#
# ## Next Steps
#
# We hope that this information has been helpful in understanding the differences between Northwind
# Health Plus and Northwind Standard. We are confident that you will find the right plan for you and
# your family. Thank you for choosing Contoso Electronics!

# %%
if analysis_result and "result" in analysis_result:
    result = analysis_result["result"]
    contents = result.get("contents", [])

    if contents:
        first_content = contents[0]
        fields = first_content.get("fields", {})
        print("📊 Extracted Fields:")
        if fields:
            for field_name, field_value in fields.items():
                field_type = field_value.get("type")
                if field_type == "string":
                    print(f"{field_name}: {field_value.get('valueString')}")
                elif field_type == "number":
                    print(f"{field_name}: {field_value.get('valueNumber')}")
                elif field_type == "date":
                    print(f"{field_name}: {field_value.get('valueDate')}")
                elif field_type == "array":
                    print(
                        f"{field_name} (array with {len(field_value.get('valueArray', []))} items):"
                    )
                    for idx, item in enumerate(
                            field_value.get('valueArray', []), 1):
                        if item.get('type') == 'object':
                            print(f"  Item {idx}:")
                            for key, val in item.get('valueObject',
                                                     {}).items():
                                if val.get('type') == 'string':
                                    print(
                                        f"    {key}: {val.get('valueString')}")
                                elif val.get('type') == 'number':
                                    print(
                                        f"    {key}: {val.get('valueNumber')}")
                                # Display confidence and source for nested fields
                                if val.get('confidence') is not None:
                                    print(
                                        f"      Confidence: {val.get('confidence'):.3f}"
                                    )
                                if val.get('source'):
                                    print(
                                        f"      Bounding Box: {val.get('source')}"
                                    )
                elif field_type == "object":
                    print(f"{field_name}: {field_value.get('valueObject')}")

                # Display confidence and bounding box for the field
                confidence = field_value.get('confidence')
                if confidence is not None:
                    print(f"  Confidence: {confidence:.3f}")
                source = field_value.get('source')
                if source:
                    print(f"  Bounding Box: {source}")
                print()
        else:
            print("No fields extracted")
        print()

        # Display content metadata
        print("📋 Content Metadata:")
        print(f"Kind: {first_content.get('kind')}")
        if first_content.get("kind") == "document":
            start_page = first_content.get("startPageNumber", 0)
            end_page = first_content.get("endPageNumber", 0)
            print(f"Pages: {start_page} - {end_page}")
            print(f"Total pages: {end_page - start_page + 1}")
        print()
else:
    print("No analysis result available")
# Out:
# 📊 Extracted Fields:
# No fields extracted
#
# 📋 Content Metadata:
# Kind: document
# Pages: 1 - 4
# Total pages: 4

# %%
# Save full result to file
saved_file_path = save_json_to_file(
    analysis_result, filename_prefix="prebuilt_invoice_analysis_result")
print(
    f"💾 Full analysis result saved. Review the complete JSON at: {saved_file_path}"
)
# Out:
# 💾 Analysis result saved to: results/prebuilt_invoice_analysis_result_20260211_133048.json
# 💾 Full analysis result saved. Review the complete JSON at: results/prebuilt_invoice_analysis_result_20260211_133048.json

# %%
with open(saved_file_path, 'r') as file:
    data = json.load(file)

print("\033[1;31;34m")
print(json.dumps(data, indent=5))
# Out:
# {
#      "id": "6c640dde-fc0b-4302-9d69-7220787bb75b",
#      "status": "Succeeded",
#      "result": {
#           "analyzerId": "prebuilt-document",
#           "apiVersion": "2025-11-01",
#           "createdAt": "2026-02-11T13:30:44Z",
#           "stringEncoding": "codePoint",
#           "warnings": [],
#           "contents": [
#                {
#                     "path": "input1",
#                     "markdown": "# Contoso Electronics Plan and Benefit Packages\n\n\n![Contoso Electronics](figures/1.1)\n\n\n<!-- PageBreak -->\n\nThis document contains information generated using a language model (Azure OpenAI). The information\ncontained in this document is only for demonstration purposes and does not reflect the opinions or\nbeliefs of Microsoft. Microsoft makes no representations or warranties of any kind, express or implied,\nabout the completeness, accuracy, reliability, suitability or availability with respect to the information\ncontained in this document.\n\nAll rights reserved to Microsoft\n\n<!-- PageBreak -->\n\nWelcome to Contoso Electronics! We are excited to offer our employees two comprehensive health\ninsurance plans through Northwind Health.\n\n\n## Northwind Health Plus\n\nNorthwind Health Plus is a comprehensive plan that provides comprehensive coverage for medical,\nvision, and dental services. This plan also offers prescription drug coverage, mental health and substance\nabuse coverage, and coverage for preventive care services. With Northwind Health Plus, you can choose\nfrom a variety of in-network providers, including primary care physicians, specialists, hospitals, and\npharmacies. This plan also offers coverage for emergency services, both in-network and out-of-network.\n\n\n## Northwind Standard\n\nNorthwind Standard is a basic plan that provides coverage for medical, vision, and dental services. This\nplan also offers coverage for preventive care services, as well as prescription drug coverage. With\nNorthwind Standard, you can choose from a variety of in-network providers, including primary care\nphysicians, specialists, hospitals, and pharmacies. This plan does not offer coverage for emergency\nservices, mental health and substance abuse coverage, or out-of-network services.\n\n\n## Comparison of Plans\n\nBoth plans offer coverage for routine physicals, well-child visits, immunizations, and other preventive\ncare services. The plans also cover preventive care services such as mammograms, colonoscopies, and\nother cancer screenings.\n\nNorthwind Health Plus offers more comprehensive coverage than Northwind Standard. This plan offers\ncoverage for emergency services, both in-network and out-of-network, as well as mental health and\nsubstance abuse coverage. Northwind Standard does not offer coverage for emergency services, mental\nhealth and substance abuse coverage, or out-of-network services.\n\nBoth plans offer coverage for prescription drugs. Northwind Health Plus offers a wider range of\nprescription drug coverage than Northwind Standard. Northwind Health Plus covers generic, brand-\nname, and specialty drugs, while Northwind Standard only covers generic and brand-name drugs.\n\nBoth plans offer coverage for vision and dental services. Northwind Health Plus offers coverage for vision\nexams, glasses, and contact lenses, as well as dental exams, cleanings, and fillings. Northwind Standard\nonly offers coverage for vision exams and glasses.\n\nBoth plans offer coverage for medical services. Northwind Health Plus offers coverage for hospital stays,\ndoctor visits, lab tests, and X-rays. Northwind Standard only offers coverage for doctor visits and lab\ntests.\n\nNorthwind Health Plus is a comprehensive plan that offers more coverage than Northwind Standard.\nNorthwind Health Plus offers coverage for emergency services, mental health and substance abuse\ncoverage, and out-of-network services, while Northwind Standard does not. Northwind Health Plus also\n\n<!-- PageBreak -->\n\noffers a wider range of prescription drug coverage than Northwind Standard. Both plans offer coverage\nfor vision and dental services, as well as medical services.\n\n\n## Cost Comparison\n\nContoso Electronics deducts the employee's portion of the healthcare cost from each paycheck. This\nmeans that the cost of the health insurance will be spread out over the course of the year, rather\nthan being paid  ...
#                     "kind": "document",
#                     "startPageNumber": 1,
#                     "endPageNumber": 4,
#                     "unit": "inch",
#                     "pages": [
#                          {
#                               "pageNumber": 1,
#                               "angle": 0.02698024,
#                               "width": 8.5,
#                               "height": 11
#                          },
#                          {
#                               "pageNumber": 2,
#                               "angle": 0,
#                               "width": 8.5,
#                               "height": 11
#                          },
#                          {
#                               "pageNumber": 3,
#                               "angle": 0,
#                               "width": 8.5,
#                               "height": 11
#                          },
#                          {
#                               "pageNumber": 4,
#                               "angle": 0,
#                               "width": 8.5,
#                               "height": 11
#                          }
#                     ],
#                     "analyzerId": "prebuilt-document",
#                     "mimeType": "application/pdf"
#                }
#           ]
#      },
#      "usage": {
#           "documentPagesStandard": 4
#      }
# }

# %% [markdown]
# ## 3. Using `prebuilt-read` for generic OCR

# %%
image_file = os.path.join(DOCS_DIR, "id.jpg")
# !ls $image_file -lh
# Out:
# -rwxrwxrwx 1 root root 74K Dec  1 15:45 documents/id.jpg

# %%
img = Image.open(image_file)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=598x378>

# %%
analyzer_id = "prebuilt-read"

print(f"🔍 Analyzing '{image_file}' with '{analyzer_id}'...")

response = client.begin_analyze_binary(
    analyzer_id=analyzer_id,
    file_location=image_file,
)

print(f"⏳ Please wait...")
analysis_result = client.poll_result(response)
print(f"✅ Done")
# Out:
# 🔍 Analyzing 'documents/id.jpg' with 'prebuilt-read'...
# ⏳ Please wait...
# ✅ Done

# %%
print("\033[1;31;34m")
print(json.dumps(analysis_result, indent=5))
# Out:
# {
#      "id": "273372fa-d346-41ae-ab0f-a51fcf598158",
#      "status": "Succeeded",
#      "result": {
#           "analyzerId": "prebuilt-read",
#           "apiVersion": "2025-11-01",
#           "createdAt": "2026-02-11T13:30:48Z",
#           "stringEncoding": "codePoint",
#           "warnings": [],
#           "contents": [
#                {
#                     "path": "input1",
#                     "markdown": "\u05e0\n\nR\u00c9PUBLIQUE FRAN\u00c7AISE\nCARTE NATIONALE D'IDENTIT\u00c9 / IDENTITY CARD\n\nNOM/Sumame\nMARTIN\n\nFR\n\nSP\u00c9CIMEN\n\nPrenoms / Given names\nMa\u0113lis-Ga\u00eblle, Marie\n\nSEXE / Sex NATIONALIT\u00c9/ Nationality\nF\nFRA\n\nDATE DE NAISS / Date of birth\n13 07 1990\n\nLIEU DE NAISSANCE / Place of birth\nPARIS\n\nNOM D'USAGE / Attemate name\n\nusage NOM D'USAGE\n\nN\u00b0 DU DOCUMENT / Document No.\nD2H6862M2\n\nDATE D'EXPIR/Expiry date\n11 02 2030\n\nSignature\n\n546497\n",
#                     "kind": "document",
#                     "startPageNumber": 1,
#                     "endPageNumber": 1,
#                     "unit": "pixel",
#                     "pages": [
#                          {
#                               "pageNumber": 1,
#                               "angle": 0.1411204,
#                               "width": 598,
#                               "height": 378,
#                               "spans": [
#                                    {
#                                         "offset": 0,
#                                         "length": 416
#                                    }
#                               ],
#                               "words": [
#                                    {
#                                         "content": "\u05e0",
#                                         "span": {
#                                              "offset": 0,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.187,
#                                         "source": "D(1,65,10,98,10,97,63,64,63)"
#                                    },
#                                    {
#                                         "content": "R\u00c9PUBLIQUE",
#                                         "span": {
#                                              "offset": 3,
#                                              "length": 10
#                                         },
#                                         "confidence": 0.989,
#                                         "source": "D(1,119,15,289,16,289,44,118,44)"
#                                    },
#                                    {
#                                         "content": "FRAN\u00c7AISE",
#                                         "span": {
#                                              "offset": 14,
#                                              "length": 9
#                                         },
#                                         "confidence": 0.995,
#                                         "source": "D(1,306,16,467,17,467,44,306,44)"
#                                    },
#                                    {
#                                         "content": "CARTE",
#                                         "span": {
#                                              "offset": 24,
#                                              "length": 5
#                                         },
#                                         "confidence": 0.994,
#                                         "source": "D(1,120,46,166,46,166,61,120,61)"
#                                    },
#                                    {
#                                         "content": "NATIONALE",
#                                         "span": {
#                                              "offset": 30,
#                                              "length": 9
#                                         },
#                                         "confidence": 0.989,
#                                         "source": "D(1,172,46,255,46,255,61,172,61)"
#                                    },
#                                    {
#                                         "content": "D'IDENTIT\u00c9",
#                                         "span": {
#                                              "offset": 40,
#                                              "length": 10
#                                         },
#                                         "confidence": 0.964,
#                                         "source": "D(1,260,46,340,46,340,61,260,61)"
#                                    },
#                                    {
#                                         "content": "/",
#                                         "span": {
#                                              "offset": 51,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.997,
#                                         "source": "D(1,344,46,350,46,350,61,344,61)"
#                                    },
#                                    {
#                                         "content": "IDENTITY",
#                                         "span": {
#                                              "offset": 53,
#                                              "length": 8
#                                         },
#                                         "confidence": 0.947,
#                                         "source": "D(1,354,46,421,46,421,61,354,61)"
#                                    },
#                                    {
#                                         "content": "CARD",
#                                         "span": {
#                                              "offset": 62,
#                                              "length": 4
#                                         },
#                                         "confidence": 0.986,
#                                         "source": "D(1,425,46,468,46,468,61,425,61)"
#                                    },
#                                    {
#                                         "content": "NOM",
#                                         "span": {
#                                              "offset": 68,
#                                              "length": 3
#                                         },
#                                         "confidence": 0.994,
#                                         "source": "D(1,238,63,260,63,260,75,238,75)"
#                                    },
#                                    {
#                                         "content": "/",
#                                         "span": {
#                                              "offset": 71,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.997,
#                                         "source": "D(1,261,63,266,63,266,75,261,75)"
#                                    },
#                                    {
#                                         "content": "Sumame",
#                                         "span": {
#                                              "offset": 72,
#                                              "length": 6
#                                         },
#                                         "confidence": 0.987,
#                                         "source": "D(1,265,63,304,63,304,75,265,75)"
#                                    },
#                                    {
#                                         "content": "MARTIN",
#                                         "span": {
#                                              "offset": 79,
#                                              "length": 6
#                                         },
#                                         "confidence": 0.997,
#                                         "source": "D(1,239,75,331,75,331,94,239,94)"
#                                    },
#                                    {
#                                         "content": "FR",
#                                         "span": {
#                                              "offset": 87,
#                                              "length": 2
#                                         },
#                                         "confidence": 0.999,
#                                         "source": "D(1,523,29,547,29,547,44,523,44)"
#                                    },
#                                    {
#                                         "content": "SP\u00c9CIMEN",
#                                         "span": {
#                                              "offset": 91,
#                                              "length": 8
#                                         },
#                                         "confidence": 0.878,
#                                         "source": "D(1,479,71,588,71,588,93,479,93)"
#                                    },
#                                    {
#                                         "content": "Prenoms",
#                                         "span": {
#                                              "offset": 101,
#                                              "length": 7
#                                         },
#                                         "confidence": 0.988,
#                                         "source": "D(1,238,117,275,117,275,130,238,130)"
#                                    },
#                                    {
#                                         "content": "/",
#                                         "span": {
#                                              "offset": 109,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.998,
#                                         "source": "D(1,276,117,280,117,280,130,276,130)"
#                                    },
#                                    {
#                                         "content": "Given",
#                                         "span": {
#                                              "offset": 111,
#                                              "length": 5
#                                         },
#                                         "confidence": 0.979,
#                                         "source": "D(1,281,117,304,117,304,130,281,130)"
#                                    },
#                                    {
#                                         "content": "names",
#                                         "span": {
#                                              "offset": 117,
#                                              "length": 5
#                                         },
#                                         "confidence": 0.991,
#                                         "source": "D(1,306,117,334,118,334,130,306,130)"
#                                    },
#                                    {
#                                         "content": "Ma\u0113lis",
#                                         "span": {
#                                              "offset": 123,
#                                              "length": 6
#                                         },
#                                         "confidence": 0.96,
#                                         "source": "D(1,238,130,298,131,298,149,238,148)"
#                                    },
#                                    {
#                                         "content": "-",
#                                         "span": {
#                                              "offset": 129,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.992,
#                                         "source": "D(1,300,131,307,131,307,149,300,149)"
#                                    },
#                                    {
#                                         "content": "Ga\u00eblle",
#                                         "span": {
#                                              "offset": 130,
#                                              "length": 6
#                                         },
#                                         "confidence": 0.775,
#                                         "source": "D(1,309,131,365,131,365,149,309,149)"
#                                    },
#                                    {
#                                         "content": ",",
#                                         "span": {
#                                              "offset": 136,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.998,
#                                         "source": "D(1,366,131,372,131,372,149,366,149)"
#                                    },
#                                    {
#                                         "content": "Marie",
#                                         "span": {
#                                              "offset": 138,
#                                              "length": 5
#                                         },
#                                         "confidence": 0.99,
#                                         "source": "D(1,376,131,431,130,431,149,376,149)"
#                                    },
#                                    {
#                                         "content": "SEXE",
#                                         "span": {
#                                              "offset": 145,
#                                              "length": 4
#                                         },
#                                         "confidence": 0.993,
#                                         "source": "D(1,238,170,265,170,265,183,238,183)"
#                                    },
#                                    {
#                                         "content": "/",
#                                         "span": {
#                                              "offset": 150,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.998,
#                                         "source": "D(1,267,170,272,170,272,183,267,183)"
#                                    },
#                                    {
#                                         "content": "Sex",
#                                         "span": {
#                                              "offset": 152,
#                                              "length": 3
#                                         },
#                                         "confidence": 0.991,
#                                         "source": "D(1,272,170,291,170,291,183,272,183)"
#                                    },
#                                    {
#                                         "content": "NATIONALIT\u00c9",
#                                         "span": {
#                                              "offset": 156,
#                                              "length": 11
#                                         },
#                                         "confidence": 0.938,
#                                         "source": "D(1,300,170,369,170,369,183,300,183)"
#                                    },
#                                    {
#                                         "content": "/",
#                                         "span": {
#                                              "offset": 167,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.998,
#                                         "source": "D(1,371,170,375,170,375,183,371,183)"
#                                    },
#                                    {
#                                         "content": "Nationality",
#                                         "span": {
#                                              "offset": 169,
#                                              "length": 11
#                                         },
#                                         "confidence": 0.959,
#                                         "source": "D(1,377,170,427,170,427,183,377,183)"
#                                    },
#                                    {
#                                         "content": "F",
#                                         "span": {
#                                              "offset": 181,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.889,
#                                         "source": "D(1,238,185,250,185,250,201,238,201)"
#                                    },
#                                    {
#                                         "content": "FRA",
#                                         "span": {
#                                              "offset": 183,
#                                              "length": 3
#                                         },
#                                         "confidence": 0.997,
#                                         "source": "D(1,300,185,337,185,337,201,300,201)"
#                                    },
#                                    {
#                                         "content": "DATE",
#                                         "span": {
#                                              "offset": 188,
#                                              "length": 4
#                                         },
#                                         "confidence": 0.989,
#                                         "source": "D(1,445,170,473,170,473,183,445,183)"
#                                    },
#                                    {
#                                         "content": "DE",
#                                         "span": {
#                                              "offset": 193,
#                                              "length": 2
#                                         },
#                                         "confidence": 0.989,
#                                         "source": "D(1,476,170,490,170,490,183,476,183)"
#                                    },
#                                    {
#                                         "content": "NAISS",
#                                         "span": {
#                                              "offset": 196,
#                                              "length": 5
#                                         },
#                                         "confidence": 0.982,
#                                         "source": "D(1,493,170,523,170,523,183,493,183)"
#                                    },
#                                    {
#                                         "content": "/",
#                                         "span": {
#                                              "offset": 202,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.981,
#                                         "source": "D(1,528,170,533,170,533,183,528,183)"
#                                    },
#                                    {
#                                         "content": "Date",
#                                         "span": {
#                                              "offset": 204,
#                                              "length": 4
#                                         },
#                                         "confidence": 0.98,
#                                         "source": "D(1,535,170,560,170,560,183,535,183)"
#                                    },
#                                    {
#                                         "content": "of",
#                                         "span": {
#                                              "offset": 209,
#                                              "length": 2
#                                         },
#                                         "confidence": 0.962,
#                                         "source": "D(1,562,170,573,170,573,183,562,183)"
#                                    },
#                                    {
#                                         "content": "birth",
#                                         "span": {
#                                              "offset": 212,
#                                              "length": 5
#                                         },
#                                         "confidence": 0.851,
#                                         "source": "D(1,573,170,597,170,597,183,573,183)"
#                                    },
#                                    {
#                                         "content": "13",
#                                         "span": {
#                                              "offset": 218,
#                                              "length": 2
#                                         },
#                                         "confidence": 0.947,
#                                         "source": "D(1,445,186,464,186,464,204,445,203)"
#                                    },
#                                    {
#                                         "content": "07",
#                                         "span": {
#                                              "offset": 221,
#                                              "length": 2
#                                         },
#                                         "confidence": 0.968,
#                                         "source": "D(1,470,186,495,186,495,204,470,204)"
#                                    },
#                                    {
#                                         "content": "1990",
#                                         "span": {
#                                              "offset": 224,
#                                              "length": 4
#                                         },
#                                         "confidence": 0.958,
#                                         "source": "D(1,500,186,549,186,549,204,500,204)"
#                                    },
#                                    {
#                                         "content": "LIEU",
#                                         "span": {
#                                              "offset": 230,
#                                              "length": 4
#                                         },
#                                         "confidence": 0.996,
#                                         "source": "D(1,237,203,260,203,260,216,237,216)"
#                                    },
#                                    {
#                                         "content": "DE",
#                                         "span": {
#                                              "offset": 235,
#                                              "length": 2
#                                         },
#                                         "confidence": 0.998,
#                                         "source": "D(1,263,203,276,203,276,216,263,216)"
#                                    },
#                                    {
#                                         "content": "NAISSANCE",
#                                         "span": {
#                                              "offset": 238,
#                                              "length": 9
#                                         },
#                                         "confidence": 0.996,
#                                         "source": "D(1,279,203,337,203,337,216,279,216)"
#                                    },
#                                    {
#                                         "content": "/",
#                                         "span": {
#                                              "offset": 248,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.999,
#                                         "source": "D(1,339,203,344,203,344,216,339,216)"
#                                    },
#                                    {
#                                         "content": "Place",
#                                         "span": {
#                                              "offset": 250,
#                                              "length": 5
#                                         },
#                                         "confidence": 0.994,
#                                         "source": "D(1,348,203,374,204,374,216,348,216)"
#                                    },
#                                    {
#                                         "content": "of",
#                                         "span": {
#                                              "offset": 256,
#                                              "length": 2
#                                         },
#                                         "confidence": 0.987,
#                                         "source": "D(1,377,204,388,204,388,217,377,216)"
#                                    },
#                                    {
#                                         "content": "birth",
#                                         "span": {
#                                              "offset": 259,
#                                              "length": 5
#                                         },
#                                         "confidence": 0.945,
#                                         "source": "D(1,388,204,410,204,410,217,388,217)"
#                                    },
#                                    {
#                                         "content": "PARIS",
#                                         "span": {
#                                              "offset": 265,
#                                              "length": 5
#                                         },
#                                         "confidence": 0.995,
#                                         "source": "D(1,238,218,290,218,290,235,238,235)"
#                                    },
#                                    {
#                                         "content": "NOM",
#                                         "span": {
#                                              "offset": 272,
#                                              "length": 3
#                                         },
#                                         "confidence": 0.997,
#                                         "source": "D(1,237,237,262,238,262,250,237,250)"
#                                    },
#                                    {
#                                         "content": "D'USAGE",
#                                         "span": {
#                                              "offset": 276,
#                                              "length": 7
#                                         },
#                                         "confidence": 0.987,
#                                         "source": "D(1,266,238,311,238,311,250,266,250)"
#                                    },
#                                    {
#                                         "content": "/",
#                                         "span": {
#                                              "offset": 284,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.998,
#                                         "source": "D(1,313,238,318,238,318,250,313,250)"
#                                    },
#                                    {
#                                         "content": "Attemate",
#                                         "span": {
#                                              "offset": 286,
#                                              "length": 8
#                                         },
#                                         "confidence": 0.785,
#                                         "source": "D(1,317,238,360,238,360,251,317,250)"
#                                    },
#                                    {
#                                         "content": "name",
#                                         "span": {
#                                              "offset": 295,
#                                              "length": 4
#                                         },
#                                         "confidence": 0.996,
#                                         "source": "D(1,362,239,390,239,390,251,362,251)"
#                                    },
#                                    {
#                                         "content": "usage",
#                                         "span": {
#                                              "offset": 301,
#                                              "length": 5
#                                         },
#                                         "confidence": 0.997,
#                                         "source": "D(1,237,253,288,252,288,271,237,271)"
#                                    },
#                                    {
#                                         "content": "NOM",
#                                         "span": {
#                                              "offset": 307,
#                                              "length": 3
#                                         },
#                                         "confidence": 0.997,
#                                         "source": "D(1,293,252,339,252,339,271,293,271)"
#                                    },
#                                    {
#                                         "content": "D'USAGE",
#                                         "span": {
#                                              "offset": 311,
#                                              "length": 7
#                                         },
#                                         "confidence": 0.985,
#                                         "source": "D(1,345,252,428,251,428,270,345,271)"
#                                    },
#                                    {
#                                         "content": "N",
#                                         "span": {
#                                              "offset": 320,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.523,
#                                         "source": "D(1,236,272,244,272,244,284,236,284)"
#                                    },
#                                    {
#                                         "content": "\u00b0",
#                                         "span": {
#                                              "offset": 321,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.487,
#                                         "source": "D(1,244,272,249,272,249,285,244,284)"
#                                    },
#                                    {
#                                         "content": "DU",
#                                         "span": {
#                                              "offset": 323,
#                                              "length": 2
#                                         },
#                                         "confidence": 0.983,
#                                         "source": "D(1,252,272,266,272,266,285,252,285)"
#                                    },
#                                    {
#                                         "content": "DOCUMENT",
#                                         "span": {
#                                              "offset": 326,
#                                              "length": 8
#                                         },
#                                         "confidence": 0.987,
#                                         "source": "D(1,270,272,329,272,329,285,270,285)"
#                                    },
#                                    {
#                                         "content": "/",
#                                         "span": {
#                                              "offset": 335,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.997,
#                                         "source": "D(1,329,272,335,272,335,285,329,285)"
#                                    },
#                                    {
#                                         "content": "Document",
#                                         "span": {
#                                              "offset": 337,
#                                              "length": 8
#                                         },
#                                         "confidence": 0.947,
#                                         "source": "D(1,338,272,388,272,388,285,338,285)"
#                                    },
#                                    {
#                                         "content": "No",
#                                         "span": {
#                                              "offset": 346,
#                                              "length": 2
#                                         },
#                                         "confidence": 0.949,
#                                         "source": "D(1,390,272,402,272,402,285,390,285)"
#                                    },
#                                    {
#                                         "content": ".",
#                                         "span": {
#                                              "offset": 348,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.498,
#                                         "source": "D(1,400,272,404,272,404,285,400,285)"
#                                    },
#                                    {
#                                         "content": "D2H6862M2",
#                                         "span": {
#                                              "offset": 350,
#                                              "length": 9
#                                         },
#                                         "confidence": 0.963,
#                                         "source": "D(1,234,286,408,287,408,309,234,309)"
#                                    },
#                                    {
#                                         "content": "DATE",
#                                         "span": {
#                                              "offset": 361,
#                                              "length": 4
#                                         },
#                                         "confidence": 0.986,
#                                         "source": "D(1,444,272,473,272,473,286,444,286)"
#                                    },
#                                    {
#                                         "content": "D'EXPIR",
#                                         "span": {
#                                              "offset": 366,
#                                              "length": 7
#                                         },
#                                         "confidence": 0.92,
#                                         "source": "D(1,476,272,517,273,517,286,476,286)"
#                                    },
#                                    {
#                                         "content": "/",
#                                         "span": {
#                                              "offset": 373,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.984,
#                                         "source": "D(1,516,273,522,273,522,286,516,286)"
#                                    },
#                                    {
#                                         "content": "Expiry",
#                                         "span": {
#                                              "offset": 374,
#                                              "length": 6
#                                         },
#                                         "confidence": 0.907,
#                                         "source": "D(1,523,273,555,273,555,287,523,286)"
#                                    },
#                                    {
#                                         "content": "date",
#                                         "span": {
#                                              "offset": 381,
#                                              "length": 4
#                                         },
#                                         "confidence": 0.913,
#                                         "source": "D(1,557,273,579,273,579,287,557,287)"
#                                    },
#                                    {
#                                         "content": "11",
#                                         "span": {
#                                              "offset": 386,
#                                              "length": 2
#                                         },
#                                         "confidence": 0.968,
#                                         "source": "D(1,445,288,462,288,462,306,445,306)"
#                                    },
#                                    {
#                                         "content": "02",
#                                         "span": {
#                                              "offset": 389,
#                                              "length": 2
#                                         },
#                                         "confidence": 0.979,
#                                         "source": "D(1,468,289,494,289,494,306,468,306)"
#                                    },
#                                    {
#                                         "content": "2030",
#                                         "span": {
#                                              "offset": 392,
#                                              "length": 4
#                                         },
#                                         "confidence": 0.962,
#                                         "source": "D(1,498,289,550,289,550,306,498,306)"
#                                    },
#                                    {
#                                         "content": "Signature",
#                                         "span": {
#                                              "offset": 398,
#                                              "length": 9
#                                         },
#                                         "confidence": 0.965,
#                                         "source": "D(1,239,312,420,314,421,357,239,358)"
#                                    },
#                                    {
#                                         "content": "546497",
#                                         "span": {
#                                              "offset": 409,
#                                              "length": 6
#                                         },
#                                         "confidence": 0.986,
#                                         "source": "D(1,443,323,564,324,564,350,443,349)"
#                                    }
#                               ],
#                               "lines": [
#                                    {
#                                         "content": "\u05e0",
#                                         "source": "D(1,65,10,98,10,97,63,64,63)",
#                                         "span": {
#                                              "offset": 0,
#                                              "length": 1
#                                         }
#                                    },
#                                    {
#                                         "content": "R\u00c9PUBLIQUE FRAN\u00c7AISE",
#                                         "source": "D(1,119,15,468,17,467,45,118,44)",
#                                         "span": {
#                                              "offset": 3,
#                                              "length": 20
#                                         }
#                                    },
#                                    {
#                                         "content": "CARTE NATIONALE D'IDENTIT\u00c9 / IDENTITY CARD",
#                                         "source": "D(1,120,46,468,46,468,61,120,61)",
#                                         "span": {
#                                              "offset": 24,
#                                              "length": 42
#                                         }
#                                    },
#                                    {
#                                         "content": "NOM/Sumame",
#                                         "source": "D(1,238,63,304,63,304,75,238,75)",
#                                         "span": {
#                                              "offset": 68,
#                                              "length": 10
#                                         }
#                                    },
#                                    {
#                                         "content": "MARTIN",
#                                         "source": "D(1,239,75,331,75,331,94,239,94)",
#                                         "span": {
#                                              "offset": 79,
#                                              "length": 6
#                                         }
#                                    },
#                                    {
#                                         "content": "FR",
#                                         "source": "D(1,523,29,547,29,547,44,523,44)",
#                                         "span": {
#                                              "offset": 87,
#                                              "length": 2
#                                         }
#                                    },
#                                    {
#                                         "content": "SP\u00c9CIMEN",
#                                         "source": "D(1,479,71,588,71,588,93,479,93)",
#                                         "span": {
#                                              "offset": 91,
#                                              "length": 8
#                                         }
#                                    },
#                                    {
#                                         "content": "Prenoms / Given names",
#                                         "source": "D(1,238,117,334,117,334,130,238,130)",
#                                         "span": {
#                                              "offset": 101,
#                                              "length": 21
#                                         }
#                                    },
#                                    {
#                                         "content": "Ma\u0113lis-Ga\u00eblle, Marie",
#                                         "source": "D(1,238,130,431,130,431,149,238,149)",
#                                         "span": {
#                                              "offset": 123,
#                                              "length": 20
#                                         }
#                                    },
#                                    {
#                                         "content": "SEXE / Sex NATIONALIT\u00c9/ Nationality",
#                                         "source": "D(1,238,170,427,170,427,183,238,183)",
#                                         "span": {
#                                              "offset": 145,
#                                              "length": 35
#                                         }
#                                    },
#                                    {
#                                         "content": "F",
#                                         "source": "D(1,238,185,250,185,250,201,238,201)",
#                                         "span": {
#                                              "offset": 181,
#                                              "length": 1
#                                         }
#                                    },
#                                    {
#                                         "content": "FRA",
#                                         "source": "D(1,300,185,337,185,337,201,300,201)",
#                                         "span": {
#                                              "offset": 183,
#                                              "length": 3
#                                         }
#                                    },
#                                    {
#                                         "content": "DATE DE NAISS / Date of birth",
#                                         "source": "D(1,445,170,597,170,597,183,445,183)",
#                                         "span": {
#                                              "offset": 188,
#                                              "length": 29
#                                         }
#                                    },
#                                    {
#                                         "content": "13 07 1990",
#                                         "source": "D(1,445,186,549,186,549,204,445,204)",
#                                         "span": {
#                                              "offset": 218,
#                                              "length": 10
#                                         }
#                                    },
#                                    {
#                                         "content": "LIEU DE NAISSANCE / Place of birth",
#                                         "source": "D(1,237,203,410,204,410,217,237,216)",
#                                         "span": {
#                                              "offset": 230,
#                                              "length": 34
#                                         }
#                                    },
#                                    {
#                                         "content": "PARIS",
#                                         "source": "D(1,238,218,290,218,290,235,238,235)",
#                                         "span": {
#                                              "offset": 265,
#                                              "length": 5
#                                         }
#                                    },
#                                    {
#                                         "content": "NOM D'USAGE / Attemate name",
#                                         "source": "D(1,237,237,390,239,390,251,237,250)",
#                                         "span": {
#                                              "offset": 272,
#                                              "length": 27
#                                         }
#                                    },
#                                    {
#                                         "content": "usage NOM D'USAGE",
#                                         "source": "D(1,237,253,428,251,428,270,237,271)",
#                                         "span": {
#                                              "offset": 301,
#                                              "length": 17
#                                         }
#                                    },
#                                    {
#                                         "content": "N\u00b0 DU DOCUMENT / Document No.",
#                                         "source": "D(1,236,272,404,272,404,285,236,285)",
#                                         "span": {
#                                              "offset": 320,
#                                              "length": 29
#                                         }
#                                    },
#                                    {
#                                         "content": "D2H6862M2",
#                                         "source": "D(1,234,286,409,287,408,310,234,309)",
#                                         "span": {
#                                              "offset": 350,
#                                              "length": 9
#                                         }
#                                    },
#                                    {
#                                         "content": "DATE D'EXPIR/Expiry date",
#                                         "source": "D(1,444,272,579,273,579,287,444,286)",
#                                         "span": {
#                                              "offset": 361,
#                                              "length": 24
#                                         }
#                                    },
#                                    {
#                                         "content": "11 02 2030",
#                                         "source": "D(1,445,288,550,289,550,306,445,306)",
#                                         "span": {
#                                              "offset": 386,
#                                              "length": 10
#                                         }
#                                    },
#                                    {
#                                         "content": "Signature",
#                                         "source": "D(1,239,312,421,313,421,358,239,358)",
#                                         "span": {
#                                              "offset": 398,
#                                              "length": 9
#                                         }
#                                    },
#                                    {
#                                         "content": "546497",
#                                         "source": "D(1,443,323,564,324,564,350,443,349)",
#                                         "span": {
#                                              "offset": 409,
#                                              "length": 6
#                                         }
#                                    }
#                               ]
#                          }
#                     ],
#                     "paragraphs": [
#                          {
#                               "content": "\u05e0",
#                               "source": "D(1,65,10,98,10,97,63,64,63)",
#                               "span": {
#                                    "offset": 0,
#                                    "length": 1
#                               }
#                          },
#                          {
#                               "content": "R\u00c9PUBLIQUE FRAN\u00c7AISE CARTE NATIONALE D'IDENTIT\u00c9 / IDENTITY CARD",
#                               "source": "D(1,118,15,468,15,468,61,118,61)",
#                               "span": {
#                                    "offset": 3,
#                                    "length": 63
#                               }
#                          },
#                          {
#                               "content": "NOM/Sumame MARTIN",
#                               "source": "D(1,238,63,330,62,331,94,238,94)",
#                               "span": {
#                                    "offset": 68,
#                                    "length": 17
#                               }
#                          },
#                          {
#                               "content": "FR",
#                               "source": "D(1,523,29,547,29,547,44,523,44)",
#                               "span": {
#                                    "offset": 87,
#                                    "length": 2
#                               }
#                          },
#                          {
#                               "content": "SP\u00c9CIMEN",
#                               "source": "D(1,479,71,588,71,588,93,479,93)",
#                               "span": {
#                                    "offset": 91,
#                                    "length": 8
#                               }
#                          },
#                          {
#                               "content": "Prenoms / Given names Ma\u0113lis-Ga\u00eblle, Marie",
#                               "source": "D(1,238,117,431,117,431,149,238,149)",
#                               "span": {
#                                    "offset": 101,
#                                    "length": 42
#                               }
#                          },
#                          {
#                               "content": "SEXE / Sex NATIONALIT\u00c9/ Nationality F FRA",
#                               "source": "D(1,238,170,427,170,427,201,238,201)",
#                               "span": {
#                                    "offset": 145,
#                                    "length": 41
#                               }
#                          },
#                          {
#                               "content": "DATE DE NAISS / Date of birth 13 07 1990",
#                               "source": "D(1,445,170,597,170,597,204,445,204)",
#                               "span": {
#                                    "offset": 188,
#                                    "length": 40
#                               }
#                          },
#                          {
#                               "content": "LIEU DE NAISSANCE / Place of birth PARIS",
#                               "source": "D(1,237,203,410,204,410,235,237,235)",
#                               "span": {
#                                    "offset": 230,
#                                    "length": 40
#                               }
#                          },
#                          {
#                               "content": "NOM D'USAGE / Attemate name",
#                               "source": "D(1,237,237,390,239,390,251,237,250)",
#                               "span": {
#                                    "offset": 272,
#                                    "length": 27
#                               }
#                          },
#                          {
#                               "content": "usage NOM D'USAGE",
#                               "source": "D(1,237,253,428,251,428,270,237,271)",
#                               "span": {
#                                    "offset": 301,
#                                    "length": 17
#                               }
#                          },
#                          {
#                               "content": "N\u00b0 DU DOCUMENT / Document No. D2H6862M2",
#                               "source": "D(1,234,271,409,272,408,310,234,309)",
#                               "span": {
#                                    "offset": 320,
#                                    "length": 39
#                               }
#                          },
#                          {
#                               "content": "DATE D'EXPIR/Expiry date 11 02 2030",
#                               "source": "D(1,444,272,579,273,579,307,444,306)",
#                               "span": {
#                                    "offset": 361,
#                                    "length": 35
#                               }
#                          },
#                          {
#                               "content": "Signature",
#                               "source": "D(1,239,312,421,313,421,358,239,358)",
#                               "span": {
#                                    "offset": 398,
#                                    "length": 9
#                               }
#                          },
#                          {
#                               "content": "546497",
#                               "source": "D(1,443,323,564,324,564,350,443,349)",
#                               "span": {
#                                    "offset": 409,
#                                    "length": 6
#                               }
#                          }
#                     ],
#                     "analyzerId": "prebuilt-read",
#                     "mimeType": "image/jpeg"
#                }
#           ]
#      },
#      "usage": {
#           "documentPagesBasic": 1
#      }
# }

# %%
print("\033[1;31;34m")
print(analysis_result['result']['contents'][0]['markdown'])
# Out:
# נ
#
# RÉPUBLIQUE FRANÇAISE
# CARTE NATIONALE D'IDENTITÉ / IDENTITY CARD
#
# NOM/Sumame
# MARTIN
#
# FR
#
# SPÉCIMEN
#
# Prenoms / Given names
# Maēlis-Gaëlle, Marie
#
# SEXE / Sex NATIONALITÉ/ Nationality
# F
# FRA
#
# DATE DE NAISS / Date of birth
# 13 07 1990
#
# LIEU DE NAISSANCE / Place of birth
# PARIS
#
# NOM D'USAGE / Attemate name
#
# usage NOM D'USAGE
#
# N° DU DOCUMENT / Document No.
# D2H6862M2
#
# DATE D'EXPIR/Expiry date
# 11 02 2030
#
# Signature
#
# 546497

# %% [markdown]
# ## 4. Using `prebuilt-idDocument`

# %%
image_file = os.path.join(DOCS_DIR, "driver.jpg")
# !ls $image_file -lh
# Out:
# -rwxrwxrwx 1 root root 1.9M Dec  2 12:43 documents/driver.jpg

# %%
img = Image.open(image_file)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1080>

# %%
analyzer_id = "prebuilt-idDocument"

print(f"🔍 Analyzing '{image_file}' with '{analyzer_id}'...")

response = client.begin_analyze_binary(
    analyzer_id=analyzer_id,
    file_location=image_file,
)

print(f"⏳ Please wait...")
analysis_result = client.poll_result(response)
print(f"✅ Done")
# Out:
# 🔍 Analyzing 'documents/driver.jpg' with 'prebuilt-idDocument'...
# ⏳ Please wait...
# ✅ Done

# %%
print("\033[1;31;34m")
print(json.dumps(analysis_result, indent=5))
# Out:
# {
#      "id": "c94de09a-a7a8-43d2-9592-699ae97502e3",
#      "status": "Succeeded",
#      "result": {
#           "analyzerId": "prebuilt-idDocument",
#           "apiVersion": "2025-11-01",
#           "createdAt": "2026-02-11T13:30:53Z",
#           "stringEncoding": "codePoint",
#           "warnings": [],
#           "contents": [
#                {
#                     "path": "input1/segment1",
#                     "category": "idDocument.generic",
#                     "markdown": "Texas\n\n\n# DRIVER LICENSE\n\nltven a. m2 Chaw DIRECTOR\n\nSAMPLE\n\n073076\n\nJanice Jample\n\n4d DL\n12345678\n9 Class AM\n4b Exp\n07/30/2021\n\n3 DOB\n07/30/1976\n1 SAMPLE\n2 JANICE\n\n8 2120 OLD MAIN STREET\nANYTOWN TX 12345-0000\n\n12 Restrictions A\n\n9a End\nP\n\n16 Hgt\n5'-04\"\n15 Sex F\n18 Eyes BLU\n\n5 DD 12345678900000000000\n\nUSA\nTX\n\n4a Iss\n07/30/2015\n",
#                     "fields": {
#                          "CountryRegion": {
#                               "type": "string",
#                               "valueString": "USA"
#                          },
#                          "Region": {
#                               "type": "string",
#                               "valueString": "TEXAS"
#                          },
#                          "DocumentNumber": {
#                               "type": "string",
#                               "valueString": "12345678",
#                               "spans": [
#                                    {
#                                         "offset": 90,
#                                         "length": 8
#                                    }
#                               ],
#                               "confidence": 0.939,
#                               "source": "D(1,769.0000,315.0000,1091.0000,314.0000,1091.0000,377.0000,769.0000,378.0000)"
#                          },
#                          "DocumentDiscriminator": {
#                               "type": "string",
#                               "valueString": "12345678900000000000",
#                               "spans": [
#                                    {
#                                         "offset": 281,
#                                         "length": 20
#                                    }
#                               ],
#                               "confidence": 0.896,
#                               "source": "D(1,819.0000,951.0000,1337.0000,950.0000,1337.0000,995.0000,819.0000,995.0000)"
#                          },
#                          "FirstName": {
#                               "type": "string",
#                               "valueString": "JANICE",
#                               "spans": [
#                                    {
#                                         "offset": 157,
#                                         "length": 6
#                                    }
#                               ],
#                               "confidence": 0.872,
#                               "source": "D(1,635.0000,591.0000,810.0000,589.0000,810.0000,631.0000,635.0000,632.0000)"
#                          },
#                          "LastName": {
#                               "type": "string",
#                               "valueString": "SAMPLE",
#                               "spans": [
#                                    {
#                                         "offset": 148,
#                                         "length": 6
#                                    }
#                               ],
#                               "confidence": 0.851,
#                               "source": "D(1,636.0000,544.0000,834.0000,542.0000,834.0000,585.0000,636.0000,587.0000)"
#                          },
#                          "Address": {
#                               "type": "string",
#                               "valueString": "2120 OLD MAIN STREET ANYTOWN TX 12345-0000",
#                               "spans": [
#                                    {
#                                         "offset": 167,
#                                         "length": 20
#                                    },
#                                    {
#                                         "offset": 188,
#                                         "length": 21
#                                    }
#                               ],
#                               "confidence": 0.873,
#                               "source": "D(1,642.0000,667.0000,1114.0000,667.0000,1114.0000,709.0000,642.0000,709.0000);D(1,642.0000,712.0000,1139.0000,712.0000,1139.0000,754.0000,642.0000,754.0000)"
#                          },
#                          "BirthDate": {
#                               "type": "date",
#                               "valueDate": "1976-07-30",
#                               "spans": [
#                                    {
#                                         "offset": 135,
#                                         "length": 10
#                                    }
#                               ],
#                               "confidence": 0.903,
#                               "source": "D(1,765.0000,451.0000,1169.0000,450.0000,1169.0000,519.0000,765.0000,520.0000)"
#                          },
#                          "ExpirationDate": {
#                               "type": "date",
#                               "valueDate": "2021-07-30",
#                               "spans": [
#                                    {
#                                         "offset": 117,
#                                         "length": 10
#                                    }
#                               ],
#                               "confidence": 0.937,
#                               "source": "D(1,1324.0000,385.0000,1655.0000,385.0000,1655.0000,446.0000,1324.0000,446.0000)"
#                          },
#                          "IssueDate": {
#                               "type": "date",
#                               "valueDate": "2015-07-30",
#                               "spans": [
#                                    {
#                                         "offset": 318,
#                                         "length": 10
#                                    }
#                               ],
#                               "confidence": 0.939,
#                               "source": "D(1,740.0000,384.0000,1073.0000,382.0000,1073.0000,442.0000,740.0000,442.0000)"
#                          },
#                          "EyeColor": {
#                               "type": "string",
#                               "valueString": "BLU",
#                               "spans": [
#                                    {
#                                         "offset": 271,
#                                         "length": 3
#                                    }
#                               ],
#                               "confidence": 0.742,
#                               "source": "D(1,1425.0000,883.0000,1563.0000,879.0000,1563.0000,938.0000,1425.0000,941.0000)"
#                          },
#                          "HairColor": {
#                               "type": "string",
#                               "confidence": 0.902
#                          },
#                          "Height": {
#                               "type": "string",
#                               "valueString": "5'-04\"",
#                               "spans": [
#                                    {
#                                         "offset": 247,
#                                         "length": 6
#                                    }
#                               ],
#                               "confidence": 0.825,
#                               "source": "D(1,829.0000,879.0000,1008.0000,879.0000,1008.0000,938.0000,829.0000,938.0000)"
#                          },
#                          "Weight": {
#                               "type": "string",
#                               "confidence": 0.835
#                          },
#                          "Sex": {
#                               "type": "string",
#                               "valueString": "F",
#                               "spans": [
#                                    {
#                                         "offset": 261,
#                                         "length": 1
#                                    }
#                               ],
#                               "confidence": 0.88,
#                               "source": "D(1,1192.0000,884.0000,1229.0000,881.0000,1229.0000,938.0000,1192.0000,937.0000)"
#                          },
#                          "Endorsements": {
#                               "type": "string",
#                               "valueString": "P",
#                               "spans": [
#                                    {
#                                         "offset": 237,
#                                         "length": 1
#                                    }
#                               ],
#                               "confidence": 0.808,
#                               "source": "D(1,1425.0000,811.0000,1467.0000,811.0000,1467.0000,865.0000,1425.0000,865.0000)"
#                          },
#                          "Restrictions": {
#                               "type": "string",
#                               "valueString": "A",
#                               "spans": [
#                                    {
#                                         "offset": 227,
#                                         "length": 1
#                                    }
#                               ],
#                               "confidence": 0.882,
#                               "source": "D(1,985.0000,814.0000,1037.0000,812.0000,1037.0000,865.0000,985.0000,866.0000)"
#                          },
#                          "PersonalNumber": {
#                               "type": "string",
#                               "confidence": 0.812
#                          },
#                          "PlaceOfBirth": {
#                               "type": "string",
#                               "confidence": 0.788
#                          },
#                          "VehicleClass": {
#                               "type": "string",
#                               "valueString": "AM",
#                               "spans": [
#                                    {
#                                         "offset": 107,
#                                         "length": 2
#                                    }
#                               ],
#                               "confidence": 0.742,
#                               "source": "D(1,1351.0000,322.0000,1455.0000,320.0000,1455.0000,377.0000,1351.0000,378.0000)"
#                          },
#                          "Category": {
#                               "type": "string",
#                               "confidence": 0.795
#                          }
#                     },
#                     "kind": "document",
#                     "startPageNumber": 1,
#                     "endPageNumber": 1,
#                     "unit": "pixel",
#                     "pages": [
#                          {
#                               "pageNumber": 1,
#                               "angle": -0.0845,
#                               "width": 1920,
#                               "height": 1080,
#                               "spans": [
#                                    {
#                                         "offset": 0,
#                                         "length": 329
#                                    }
#                               ],
#                               "words": [
#                                    {
#                                         "content": "Texas",
#                                         "span": {
#                                              "offset": 0,
#                                              "length": 5
#                                         },
#                                         "confidence": 0.961,
#                                         "source": "D(1,244,70,772,79,771,268,241,254)"
#                                    },
#                                    {
#                                         "content": "DRIVER",
#                                         "span": {
#                                              "offset": 10,
#                                              "length": 6
#                                         },
#                                         "confidence": 0.997,
#                                         "source": "D(1,905,146,1182,145,1182,205,905,206)"
#                                    },
#                                    {
#                                         "content": "LICENSE",
#                                         "span": {
#                                              "offset": 17,
#                                              "length": 7
#                                         },
#                                         "confidence": 0.997,
#                                         "source": "D(1,1202,145,1531,145,1531,205,1202,205)"
#                                    },
#                                    {
#                                         "content": "ltven",
#                                         "span": {
#                                              "offset": 26,
#                                              "length": 5
#                                         },
#                                         "confidence": 0.387,
#                                         "source": "D(1,201,289,328,290,327,328,200,327)"
#                                    },
#                                    {
#                                         "content": "a",
#                                         "span": {
#                                              "offset": 32,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.525,
#                                         "source": "D(1,327,290,359,290,358,328,326,328)"
#                                    },
#                                    {
#                                         "content": ".",
#                                         "span": {
#                                              "offset": 33,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.895,
#                                         "source": "D(1,338,290,369,290,368,328,337,328)"
#                                    },
#                                    {
#                                         "content": "m2",
#                                         "span": {
#                                              "offset": 35,
#                                              "length": 2
#                                         },
#                                         "confidence": 0.4,
#                                         "source": "D(1,354,290,422,290,421,328,353,328)"
#                                    },
#                                    {
#                                         "content": "Chaw",
#                                         "span": {
#                                              "offset": 38,
#                                              "length": 4
#                                         },
#                                         "confidence": 0.298,
#                                         "source": "D(1,411,290,505,290,504,328,410,328)"
#                                    },
#                                    {
#                                         "content": "DIRECTOR",
#                                         "span": {
#                                              "offset": 43,
#                                              "length": 8
#                                         },
#                                         "confidence": 0.962,
#                                         "source": "D(1,503,290,613,291,612,327,502,328)"
#                                    },
#                                    {
#                                         "content": "SAMPLE",
#                                         "span": {
#                                              "offset": 53,
#                                              "length": 6
#                                         },
#                                         "confidence": 0.89,
#                                         "source": "D(1,199,546,199,363,238,364,237,546)"
#                                    },
#                                    {
#                                         "content": "073076",
#                                         "span": {
#                                              "offset": 61,
#                                              "length": 6
#                                         },
#                                         "confidence": 0.964,
#                                         "source": "D(1,263,754,558,758,558,845,263,844)"
#                                    },
#                                    {
#                                         "content": "Janice",
#                                         "span": {
#                                              "offset": 69,
#                                              "length": 6
#                                         },
#                                         "confidence": 0.777,
#                                         "source": "D(1,184,873,414,873,414,988,184,989)"
#                                    },
#                                    {
#                                         "content": "Jample",
#                                         "span": {
#                                              "offset": 76,
#                                              "length": 6
#                                         },
#                                         "confidence": 0.208,
#                                         "source": "D(1,414,873,667,876,668,984,414,988)"
#                                    },
#                                    {
#                                         "content": "4d",
#                                         "span": {
#                                              "offset": 84,
#                                              "length": 2
#                                         },
#                                         "confidence": 0.938,
#                                         "source": "D(1,612,340,653,339,653,377,612,377)"
#                                    },
#                                    {
#                                         "content": "DL",
#                                         "span": {
#                                              "offset": 87,
#                                              "length": 2
#                                         },
#                                         "confidence": 0.98,
#                                         "source": "D(1,665,339,721,339,721,378,665,377)"
#                                    },
#                                    {
#                                         "content": "12345678",
#                                         "span": {
#                                              "offset": 90,
#                                              "length": 8
#                                         },
#                                         "confidence": 0.969,
#                                         "source": "D(1,769,315,1091,314,1091,377,769,378)"
#                                    },
#                                    {
#                                         "content": "9",
#                                         "span": {
#                                              "offset": 99,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.988,
#                                         "source": "D(1,1178,329,1198,328,1198,381,1178,381)"
#                                    },
#                                    {
#                                         "content": "Class",
#                                         "span": {
#                                              "offset": 101,
#                                              "length": 5
#                                         },
#                                         "confidence": 0.995,
#                                         "source": "D(1,1218,327,1329,323,1329,378,1218,380)"
#                                    },
#                                    {
#                                         "content": "AM",
#                                         "span": {
#                                              "offset": 107,
#                                              "length": 2
#                                         },
#                                         "confidence": 0.993,
#                                         "source": "D(1,1351,322,1455,320,1455,377,1351,378)"
#                                    },
#                                    {
#                                         "content": "4b",
#                                         "span": {
#                                              "offset": 110,
#                                              "length": 2
#                                         },
#                                         "confidence": 0.941,
#                                         "source": "D(1,1178,405,1218,405,1218,447,1178,447)"
#                                    },
#                                    {
#                                         "content": "Exp",
#                                         "span": {
#                                              "offset": 113,
#                                              "length": 3
#                                         },
#                                         "confidence": 0.948,
#                                         "source": "D(1,1230,405,1306,404,1306,448,1230,447)"
#                                    },
#                                    {
#                                         "content": "07/30/2021",
#                                         "span": {
#                                              "offset": 117,
#                                              "length": 10
#                                         },
#                                         "confidence": 0.951,
#                                         "source": "D(1,1324,385,1655,385,1655,446,1324,446)"
#                                    },
#                                    {
#                                         "content": "3",
#                                         "span": {
#                                              "offset": 129,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.992,
#                                         "source": "D(1,610,479,633,479,633,517,610,517)"
#                                    },
#                                    {
#                                         "content": "DOB",
#                                         "span": {
#                                              "offset": 131,
#                                              "length": 3
#                                         },
#                                         "confidence": 0.979,
#                                         "source": "D(1,661,478,756,477,756,517,661,517)"
#                                    },
#                                    {
#                                         "content": "07/30/1976",
#                                         "span": {
#                                              "offset": 135,
#                                              "length": 10
#                                         },
#                                         "confidence": 0.959,
#                                         "source": "D(1,765,451,1169,450,1169,519,765,520)"
#                                    },
#                                    {
#                                         "content": "1",
#                                         "span": {
#                                              "offset": 146,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.944,
#                                         "source": "D(1,609,544,628,544,628,587,609,587)"
#                                    },
#                                    {
#                                         "content": "SAMPLE",
#                                         "span": {
#                                              "offset": 148,
#                                              "length": 6
#                                         },
#                                         "confidence": 0.948,
#                                         "source": "D(1,636,544,834,542,834,585,636,587)"
#                                    },
#                                    {
#                                         "content": "2",
#                                         "span": {
#                                              "offset": 155,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.877,
#                                         "source": "D(1,610,591,632,591,632,632,610,633)"
#                                    },
#                                    {
#                                         "content": "JANICE",
#                                         "span": {
#                                              "offset": 157,
#                                              "length": 6
#                                         },
#                                         "confidence": 0.822,
#                                         "source": "D(1,635,591,810,589,810,631,635,632)"
#                                    },
#                                    {
#                                         "content": "8",
#                                         "span": {
#                                              "offset": 165,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.963,
#                                         "source": "D(1,614,669,633,669,633,709,614,709)"
#                                    },
#                                    {
#                                         "content": "2120",
#                                         "span": {
#                                              "offset": 167,
#                                              "length": 4
#                                         },
#                                         "confidence": 0.986,
#                                         "source": "D(1,642,669,732,668,732,709,642,709)"
#                                    },
#                                    {
#                                         "content": "OLD",
#                                         "span": {
#                                              "offset": 172,
#                                              "length": 3
#                                         },
#                                         "confidence": 0.996,
#                                         "source": "D(1,741,668,827,668,827,709,741,709)"
#                                    },
#                                    {
#                                         "content": "MAIN",
#                                         "span": {
#                                              "offset": 176,
#                                              "length": 4
#                                         },
#                                         "confidence": 0.997,
#                                         "source": "D(1,839,668,941,668,941,709,839,709)"
#                                    },
#                                    {
#                                         "content": "STREET",
#                                         "span": {
#                                              "offset": 181,
#                                              "length": 6
#                                         },
#                                         "confidence": 0.996,
#                                         "source": "D(1,953,668,1114,667,1114,709,953,709)"
#                                    },
#                                    {
#                                         "content": "ANYTOWN",
#                                         "span": {
#                                              "offset": 188,
#                                              "length": 7
#                                         },
#                                         "confidence": 0.97,
#                                         "source": "D(1,642,713,847,713,847,754,642,754)"
#                                    },
#                                    {
#                                         "content": "TX",
#                                         "span": {
#                                              "offset": 196,
#                                              "length": 2
#                                         },
#                                         "confidence": 0.953,
#                                         "source": "D(1,860,713,912,713,912,754,860,754)"
#                                    },
#                                    {
#                                         "content": "12345-0000",
#                                         "span": {
#                                              "offset": 199,
#                                              "length": 10
#                                         },
#                                         "confidence": 0.936,
#                                         "source": "D(1,924,713,1139,712,1139,754,924,754)"
#                                    },
#                                    {
#                                         "content": "12",
#                                         "span": {
#                                              "offset": 211,
#                                              "length": 2
#                                         },
#                                         "confidence": 0.926,
#                                         "source": "D(1,695,821,733,821,733,869,695,868)"
#                                    },
#                                    {
#                                         "content": "Restrictions",
#                                         "span": {
#                                              "offset": 214,
#                                              "length": 12
#                                         },
#                                         "confidence": 0.993,
#                                         "source": "D(1,744,821,978,814,978,866,744,869)"
#                                    },
#                                    {
#                                         "content": "A",
#                                         "span": {
#                                              "offset": 227,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.993,
#                                         "source": "D(1,985,814,1037,812,1037,865,985,866)"
#                                    },
#                                    {
#                                         "content": "9a",
#                                         "span": {
#                                              "offset": 230,
#                                              "length": 2
#                                         },
#                                         "confidence": 0.971,
#                                         "source": "D(1,1264,828,1303,827,1303,866,1264,865)"
#                                    },
#                                    {
#                                         "content": "End",
#                                         "span": {
#                                              "offset": 233,
#                                              "length": 3
#                                         },
#                                         "confidence": 0.994,
#                                         "source": "D(1,1313,827,1392,826,1392,866,1313,866)"
#                                    },
#                                    {
#                                         "content": "P",
#                                         "span": {
#                                              "offset": 237,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.473,
#                                         "source": "D(1,1425,811,1467,811,1467,865,1425,865)"
#                                    },
#                                    {
#                                         "content": "16",
#                                         "span": {
#                                              "offset": 240,
#                                              "length": 2
#                                         },
#                                         "confidence": 0.984,
#                                         "source": "D(1,694,899,732,899,732,941,694,940)"
#                                    },
#                                    {
#                                         "content": "Hgt",
#                                         "span": {
#                                              "offset": 243,
#                                              "length": 3
#                                         },
#                                         "confidence": 0.986,
#                                         "source": "D(1,743,899,818,897,818,941,743,941)"
#                                    },
#                                    {
#                                         "content": "5",
#                                         "span": {
#                                              "offset": 247,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.998,
#                                         "source": "D(1,829,880,865,880,865,937,829,938)"
#                                    },
#                                    {
#                                         "content": "'",
#                                         "span": {
#                                              "offset": 248,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.973,
#                                         "source": "D(1,863,880,884,880,884,937,863,937)"
#                                    },
#                                    {
#                                         "content": "-",
#                                         "span": {
#                                              "offset": 249,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.996,
#                                         "source": "D(1,882,880,905,880,905,937,882,937)"
#                                    },
#                                    {
#                                         "content": "04",
#                                         "span": {
#                                              "offset": 250,
#                                              "length": 2
#                                         },
#                                         "confidence": 0.999,
#                                         "source": "D(1,902,880,977,880,977,937,902,937)"
#                                    },
#                                    {
#                                         "content": "\"",
#                                         "span": {
#                                              "offset": 252,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.981,
#                                         "source": "D(1,978,880,1008,879,1008,937,978,937)"
#                                    },
#                                    {
#                                         "content": "15",
#                                         "span": {
#                                              "offset": 254,
#                                              "length": 2
#                                         },
#                                         "confidence": 0.984,
#                                         "source": "D(1,1052,890,1092,889,1092,938,1052,939)"
#                                    },
#                                    {
#                                         "content": "Sex",
#                                         "span": {
#                                              "offset": 257,
#                                              "length": 3
#                                         },
#                                         "confidence": 0.995,
#                                         "source": "D(1,1102,889,1179,885,1179,937,1102,938)"
#                                    },
#                                    {
#                                         "content": "F",
#                                         "span": {
#                                              "offset": 261,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.992,
#                                         "source": "D(1,1192,884,1229,881,1229,938,1192,937)"
#                                    },
#                                    {
#                                         "content": "18",
#                                         "span": {
#                                              "offset": 263,
#                                              "length": 2
#                                         },
#                                         "confidence": 0.972,
#                                         "source": "D(1,1269,886,1305,886,1305,942,1269,942)"
#                                    },
#                                    {
#                                         "content": "Eyes",
#                                         "span": {
#                                              "offset": 266,
#                                              "length": 4
#                                         },
#                                         "confidence": 0.979,
#                                         "source": "D(1,1312,886,1403,884,1403,941,1312,942)"
#                                    },
#                                    {
#                                         "content": "BLU",
#                                         "span": {
#                                              "offset": 271,
#                                              "length": 3
#                                         },
#                                         "confidence": 0.982,
#                                         "source": "D(1,1425,883,1563,879,1563,938,1425,941)"
#                                    },
#                                    {
#                                         "content": "5",
#                                         "span": {
#                                              "offset": 276,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.967,
#                                         "source": "D(1,696,951,717,951,717,996,696,996)"
#                                    },
#                                    {
#                                         "content": "DD",
#                                         "span": {
#                                              "offset": 278,
#                                              "length": 2
#                                         },
#                                         "confidence": 0.93,
#                                         "source": "D(1,744,951,805,951,805,995,744,996)"
#                                    },
#                                    {
#                                         "content": "12345678900000000000",
#                                         "span": {
#                                              "offset": 281,
#                                              "length": 20
#                                         },
#                                         "confidence": 0.943,
#                                         "source": "D(1,819,951,1337,950,1337,995,819,995)"
#                                    },
#                                    {
#                                         "content": "USA",
#                                         "span": {
#                                              "offset": 303,
#                                              "length": 3
#                                         },
#                                         "confidence": 0.992,
#                                         "source": "D(1,1592,89,1679,89,1679,127,1592,127)"
#                                    },
#                                    {
#                                         "content": "TX",
#                                         "span": {
#                                              "offset": 307,
#                                              "length": 2
#                                         },
#                                         "confidence": 0.972,
#                                         "source": "D(1,1610,131,1662,131,1662,168,1610,168)"
#                                    },
#                                    {
#                                         "content": "4a",
#                                         "span": {
#                                              "offset": 311,
#                                              "length": 2
#                                         },
#                                         "confidence": 0.956,
#                                         "source": "D(1,611,409,652,408,652,444,611,443)"
#                                    },
#                                    {
#                                         "content": "Iss",
#                                         "span": {
#                                              "offset": 314,
#                                              "length": 3
#                                         },
#                                         "confidence": 0.849,
#                                         "source": "D(1,664,408,723,406,723,442,664,443)"
#                                    },
#                                    {
#                                         "content": "07/30/2015",
#                                         "span": {
#                                              "offset": 318,
#                                              "length": 10
#                                         },
#                                         "confidence": 0.966,
#                                         "source": "D(1,740,384,1073,382,1073,442,740,442)"
#                                    }
#                               ],
#                               "lines": [
#                                    {
#                                         "content": "Texas",
#                                         "source": "D(1,244,70,772,78,771,269,241,261)",
#                                         "span": {
#                                              "offset": 0,
#                                              "length": 5
#                                         }
#                                    },
#                                    {
#                                         "content": "DRIVER LICENSE",
#                                         "source": "D(1,905,146,1531,145,1531,205,905,206)",
#                                         "span": {
#                                              "offset": 10,
#                                              "length": 14
#                                         }
#                                    },
#                                    {
#                                         "content": "ltven a. m2 Chaw DIRECTOR",
#                                         "source": "D(1,200,289,613,291,612,329,200,328)",
#                                         "span": {
#                                              "offset": 26,
#                                              "length": 25
#                                         }
#                                    },
#                                    {
#                                         "content": "SAMPLE",
#                                         "source": "D(1,199,547,199,363,238,363,238,547)",
#                                         "span": {
#                                              "offset": 53,
#                                              "length": 6
#                                         }
#                                    },
#                                    {
#                                         "content": "073076",
#                                         "source": "D(1,263,754,558,756,558,845,263,844)",
#                                         "span": {
#                                              "offset": 61,
#                                              "length": 6
#                                         }
#                                    },
#                                    {
#                                         "content": "Janice Jample",
#                                         "source": "D(1,183,873,667,872,668,987,184,989)",
#                                         "span": {
#                                              "offset": 69,
#                                              "length": 13
#                                         }
#                                    },
#                                    {
#                                         "content": "4d DL",
#                                         "source": "D(1,612,339,721,339,721,378,612,377)",
#                                         "span": {
#                                              "offset": 84,
#                                              "length": 5
#                                         }
#                                    },
#                                    {
#                                         "content": "12345678",
#                                         "source": "D(1,769,315,1091,314,1091,378,769,378)",
#                                         "span": {
#                                              "offset": 90,
#                                              "length": 8
#                                         }
#                                    },
#                                    {
#                                         "content": "9 Class AM",
#                                         "source": "D(1,1178,324,1455,320,1455,377,1178,381)",
#                                         "span": {
#                                              "offset": 99,
#                                              "length": 10
#                                         }
#                                    },
#                                    {
#                                         "content": "4b Exp",
#                                         "source": "D(1,1178,404,1306,404,1306,448,1178,448)",
#                                         "span": {
#                                              "offset": 110,
#                                              "length": 6
#                                         }
#                                    },
#                                    {
#                                         "content": "07/30/2021",
#                                         "source": "D(1,1324,385,1655,385,1655,446,1324,446)",
#                                         "span": {
#                                              "offset": 117,
#                                              "length": 10
#                                         }
#                                    },
#                                    {
#                                         "content": "3 DOB",
#                                         "source": "D(1,610,477,756,477,756,517,610,517)",
#                                         "span": {
#                                              "offset": 129,
#                                              "length": 5
#                                         }
#                                    },
#                                    {
#                                         "content": "07/30/1976",
#                                         "source": "D(1,764,451,1169,450,1169,519,765,520)",
#                                         "span": {
#                                              "offset": 135,
#                                              "length": 10
#                                         }
#                                    },
#                                    {
#                                         "content": "1 SAMPLE",
#                                         "source": "D(1,609,544,834,542,834,585,609,587)",
#                                         "span": {
#                                              "offset": 146,
#                                              "length": 8
#                                         }
#                                    },
#                                    {
#                                         "content": "2 JANICE",
#                                         "source": "D(1,609,590,810,589,811,631,610,633)",
#                                         "span": {
#                                              "offset": 155,
#                                              "length": 8
#                                         }
#                                    },
#                                    {
#                                         "content": "8 2120 OLD MAIN STREET",
#                                         "source": "D(1,614,667,1114,667,1114,709,614,709)",
#                                         "span": {
#                                              "offset": 165,
#                                              "length": 22
#                                         }
#                                    },
#                                    {
#                                         "content": "ANYTOWN TX 12345-0000",
#                                         "source": "D(1,642,713,1139,712,1139,754,642,754)",
#                                         "span": {
#                                              "offset": 188,
#                                              "length": 21
#                                         }
#                                    },
#                                    {
#                                         "content": "12 Restrictions A",
#                                         "source": "D(1,695,820,1037,812,1037,865,695,869)",
#                                         "span": {
#                                              "offset": 211,
#                                              "length": 17
#                                         }
#                                    },
#                                    {
#                                         "content": "9a End",
#                                         "source": "D(1,1264,827,1392,826,1392,866,1264,867)",
#                                         "span": {
#                                              "offset": 230,
#                                              "length": 6
#                                         }
#                                    },
#                                    {
#                                         "content": "P",
#                                         "source": "D(1,1425,811,1467,811,1467,865,1425,865)",
#                                         "span": {
#                                              "offset": 237,
#                                              "length": 1
#                                         }
#                                    },
#                                    {
#                                         "content": "16 Hgt",
#                                         "source": "D(1,694,898,818,897,818,941,694,941)",
#                                         "span": {
#                                              "offset": 240,
#                                              "length": 6
#                                         }
#                                    },
#                                    {
#                                         "content": "5'-04\"",
#                                         "source": "D(1,829,879,1008,879,1008,937,829,938)",
#                                         "span": {
#                                              "offset": 247,
#                                              "length": 6
#                                         }
#                                    },
#                                    {
#                                         "content": "15 Sex F",
#                                         "source": "D(1,1052,882,1229,881,1229,938,1052,939)",
#                                         "span": {
#                                              "offset": 254,
#                                              "length": 8
#                                         }
#                                    },
#                                    {
#                                         "content": "18 Eyes BLU",
#                                         "source": "D(1,1269,885,1563,879,1563,938,1269,943)",
#                                         "span": {
#                                              "offset": 263,
#                                              "length": 11
#                                         }
#                                    },
#                                    {
#                                         "content": "5 DD 12345678900000000000",
#                                         "source": "D(1,696,950,1337,950,1337,995,696,996)",
#                                         "span": {
#                                              "offset": 276,
#                                              "length": 25
#                                         }
#                                    },
#                                    {
#                                         "content": "USA",
#                                         "source": "D(1,1592,89,1679,89,1679,127,1592,127)",
#                                         "span": {
#                                              "offset": 303,
#                                              "length": 3
#                                         }
#                                    },
#                                    {
#                                         "content": "TX",
#                                         "source": "D(1,1610,131,1662,131,1662,168,1610,168)",
#                                         "span": {
#                                              "offset": 307,
#                                              "length": 2
#                                         }
#                                    },
#                                    {
#                                         "content": "4a Iss",
#                                         "source": "D(1,610,409,723,406,723,442,611,444)",
#                                         "span": {
#                                              "offset": 311,
#                                              "length": 6
#                                         }
#                                    },
#                                    {
#                                         "content": "07/30/2015",
#                                         "source": "D(1,740,383,1073,382,1074,442,740,442)",
#                                         "span": {
#                                              "offset": 318,
#                                              "length": 10
#                                         }
#                                    }
#                               ]
#                          }
#                     ],
#                     "paragraphs": [
#                          {
#                               "content": "Texas",
#                               "source": "D(1,244,70,773,78,771,269,241,261)",
#                               "span": {
#                                    "offset": 0,
#                                    "length": 5
#                               }
#                          },
#                          {
#                               "role": "title",
#                               "content": "DRIVER LICENSE",
#                               "source": "D(1,905,146,1531,145,1531,205,905,206)",
#                               "span": {
#                                    "offset": 8,
#                                    "length": 16
#                               }
#                          },
#                          {
#                               "content": "ltven a. m2 Chaw DIRECTOR",
#                               "source": "D(1,200,289,613,291,612,329,200,328)",
#                               "span": {
#                                    "offset": 26,
#                                    "length": 25
#                               }
#                          },
#                          {
#                               "content": "SAMPLE",
#                               "source": "D(1,199,363,238,363,238,547,199,547)",
#                               "span": {
#                                    "offset": 53,
#                                    "length": 6
#                               }
#                          },
#                          {
#                               "content": "073076",
#                               "source": "D(1,263,754,558,756,558,845,263,844)",
#                               "span": {
#                                    "offset": 61,
#                                    "length": 6
#                               }
#                          },
#                          {
#                               "content": "Janice Jample",
#                               "source": "D(1,183,873,667,871,668,987,184,989)",
#                               "span": {
#                                    "offset": 69,
#                                    "length": 13
#                               }
#                          },
#                          {
#                               "content": "4d DL 12345678 9 Class AM 4b Exp 07/30/2021",
#                               "source": "D(1,612,306,1657,323,1655,455,610,439)",
#                               "span": {
#                                    "offset": 84,
#                                    "length": 43
#                               }
#                          },
#                          {
#                               "content": "3 DOB 07/30/1976 1 SAMPLE 2 JANICE",
#                               "source": "D(1,608,452,1169,448,1171,628,610,633)",
#                               "span": {
#                                    "offset": 129,
#                                    "length": 34
#                               }
#                          },
#                          {
#                               "content": "8 2120 OLD MAIN STREET ANYTOWN TX 12345-0000",
#                               "source": "D(1,614,667,1139,667,1139,754,614,754)",
#                               "span": {
#                                    "offset": 165,
#                                    "length": 44
#                               }
#                          },
#                          {
#                               "content": "12 Restrictions A",
#                               "source": "D(1,695,816,1037,812,1038,865,695,869)",
#                               "span": {
#                                    "offset": 211,
#                                    "length": 17
#                               }
#                          },
#                          {
#                               "content": "9a End P",
#                               "source": "D(1,1263,814,1467,810,1468,865,1264,869)",
#                               "span": {
#                                    "offset": 230,
#                                    "length": 8
#                               }
#                          },
#                          {
#                               "content": "16 Hgt 5'-04\" 15 Sex F 18 Eyes BLU",
#                               "source": "D(1,694,879,1563,879,1563,943,694,943)",
#                               "span": {
#                                    "offset": 240,
#                                    "length": 34
#                               }
#                          },
#                          {
#                               "content": "5 DD 12345678900000000000",
#                               "source": "D(1,696,950,1337,950,1337,995,696,996)",
#                               "span": {
#                                    "offset": 276,
#                                    "length": 25
#                               }
#                          },
#                          {
#                               "content": "USA TX",
#                               "source": "D(1,1592,89,1679,89,1679,169,1592,168)",
#                               "span": {
#                                    "offset": 303,
#                                    "length": 6
#                               }
#                          },
#                          {
#                               "content": "4a Iss 07/30/2015",
#                               "source": "D(1,610,383,1073,381,1074,442,610,444)",
#                               "span": {
#                                    "offset": 311,
#                                    "length": 17
#                               }
#                          }
#                     ],
#                     "sections": [
#                          {
#                               "span": {
#                                    "offset": 0,
#                                    "length": 328
#                               },
#                               "elements": [
#                                    "/sections/1",
#                                    "/sections/2"
#                               ]
#                          },
#                          {
#                               "span": {
#                                    "offset": 0,
#                                    "length": 5
#                               },
#                               "elements": [
#                                    "/paragraphs/0"
#                               ]
#                          },
#                          {
#                               "span": {
#                                    "offset": 8,
#                                    "length": 320
#                               },
#                               "elements": [
#                                    "/paragraphs/1",
#                                    "/paragraphs/2",
#                                    "/paragraphs/3",
#                                    "/paragraphs/4",
#                                    "/paragraphs/5",
#                                    "/paragraphs/6",
#                                    "/paragraphs/7",
#                                    "/paragraphs/8",
#                                    "/paragraphs/9",
#                                    "/paragraphs/10",
#                                    "/paragraphs/11",
#                                    "/paragraphs/12",
#                                    "/paragraphs/13",
#                                    "/paragraphs/14"
#                               ]
#                          }
#                     ],
#                     "analyzerId": "prebuilt-idDocument.generic",
#                     "mimeType": "image/jpeg"
#                }
#           ]
#      },
#      "usage": {
#           "documentPagesStandard": 1,
#           "contextualizationTokens": 1000,
#           "tokens": {
#                "gpt-4.1-input": 5180,
#                "gpt-4.1-output": 339,
#                "text-embedding-3-large": 139
#           }
#      }
# }

# %% [markdown]
# ## 5. Using `prebuilt-layout` on document

# %%
document_file = os.path.join(DOCS_DIR, "document.pdf")
# !ls $document_file -lh
# Out:
# -rwxrwxrwx 1 root root 260K Nov 27 09:04 documents/document.pdf

# %%
analyzer_id = "prebuilt-layout"

print(f"🔍 Analyzing '{document_file}' with '{analyzer_id}'...")

response = client.begin_analyze_binary(
    analyzer_id=analyzer_id,
    file_location=document_file,
)

print(f"⏳ Please wait...")
analysis_result = client.poll_result(response)
print(f"✅ Done")
# Out:
# 🔍 Analyzing 'documents/document.pdf' with 'prebuilt-layout'...
# ⏳ Please wait...
# ✅ Done

# %%
display(Markdown(analysis_result['result']['contents'][0]['markdown']))
# Out:
# CONTOSO LTD.
#
#
# # INVOICE
#
# Contoso Headquarters
# 123 456th St
# New York, NY, 10001
#
# INVOICE: INV-100
#
# INVOICE DATE: 11/15/2019
#
# DUE DATE: 12/15/2019
#
# CUSTOMER NAME: MICROSOFT CORPORATION
#
# SERVICE PERIOD: 10/14/2019 - 11/14/2019
#
# CUSTOMER ID: CID-12345
#
# Microsoft Corp
# 123 Other St,
# Redmond WA, 98052
#
# BILL TO:
# Microsoft Finance
# 123 Bill St,
# Redmond WA, 98052
#
# SHIP TO:
# Microsoft Delivery
# 123 Ship St,
# Redmond WA, 98052
#
# SERVICE ADDRESS:
# Microsoft Services
# 123 Service St,
# Redmond WA, 98052
#
#
# <table>
# <tr>
# <th>SALESPERSON</th>
# <th>P.O. NUMBER</th>
# <th>REQUISITIONER</th>
# <th>SHIPPED VIA</th>
# <th>F.O.B. POINT</th>
# <th>TERMS</th>
# </tr>
# <tr>
# <td></td>
# <td>PO-3333</td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# </table>
#
#
# <table>
# <tr>
# <th>DATE</th>
# <th>ITEM CODE</th>
# <th>DESCRIPTION</th>
# <th>QTY</th>
# <th>UM</th>
# <th>PRICE</th>
# <th>TAX</th>
# <th>AMOUNT</th>
# </tr>
# <tr>
# <td>3/4/2021</td>
# <td>A123</td>
# <td>Consulting Services</td>
# <td>2</td>
# <td>hours</td>
# <td>$30.00</td>
# <td>$6.00</td>
# <td>$60.00</td>
# </tr>
# <tr>
# <td>3/5/2021</td>
# <td>B456</td>
# <td>Document Fee</td>
# <td>3</td>
# <td></td>
# <td>$10.00</td>
# <td>$3.00</td>
# <td>$30.00</td>
# </tr>
# <tr>
# <td>3/6/2021</td>
# <td>C789</td>
# <td>Printing Fee</td>
# <td>10</td>
# <td>pages</td>
# <td>$1.00</td>
# <td>$1.00</td>
# <td>$10.00</td>
# </tr>
# </table>
#
#
# <table>
# <tr>
# <th>SUBTOTAL</th>
# <th>$100.00</th>
# </tr>
# <tr>
# <th>SALES TAX</th>
# <th>$10.00</th>
# </tr>
# <tr>
# <th>TOTAL</th>
# <th>$110.00</th>
# </tr>
# <tr>
# <th>PREVIOUS UNPAID BALANCE</th>
# <th>$500.00</th>
# </tr>
# <tr>
# <th>AMOUNT DUE</th>
# <th>$610.00</th>
# </tr>
# </table>
#
#
# THANK YOU FOR YOUR BUSINESS!
#
# REMIT TO:
# Contoso Billing
# 123 Remit St
# New York, NY, 10001
#
# <!-- PageBreak -->
#
#
# # Contoso Bank
#
# Statement for: John Smith
# Account Number: 1234 5678 9012
# Statement Period: June 1, 2025 - June 30, 2025
#
#
# ## Account Summary
#
#
# <table>
# <tr>
# <th>Beginning Balance</th>
# <th>$3,200.00</th>
# </tr>
# <tr>
# <th>Total Deposits</th>
# <th>$2,500.00</th>
# </tr>
# <tr>
# <th>Total Withdrawals</th>
# <th>$ 650.00</th>
# </tr>
# <tr>
# <th>Ending Balance</th>
# <th>$5,050.00</th>
# </tr>
# </table>
#
#
# ## Transaction History
#
#
# <table>
# <tr>
# <th>Date</th>
# <th>Description</th>
# <th>Withdrawals</th>
# <th>Deposits</th>
# <th>Balance</th>
# </tr>
# <tr>
# <td>06/01/2025</td>
# <td>Opening Balance</td>
# <td></td>
# <td></td>
# <td>$3,200.00</td>
# </tr>
# <tr>
# <td>06/02/2025</td>
# <td>Payroll Deposit</td>
# <td></td>
# <td>$1,200.00</td>
# <td>$4,400.00</td>
# </tr>
# <tr>
# <td>06/03/2025</td>
# <td>Coffee Shop</td>
# <td>$5.75</td>
# <td></td>
# <td>$4,394.25</td>
# </tr>
# <tr>
# <td>06/05/2025</td>
# <td>Online Shopping Company</td>
# <td>$89.99</td>
# <td></td>
# <td>$4,304.26</td>
# </tr>
# <tr>
# <td>06/07/2025</td>
# <td>ATM Withdrawal</td>
# <td>$100.00</td>
# <td></td>
# <td>$4,204.26</td>
# </tr>
# <tr>
# <td>06/10/2025</td>
# <td>Utility Provider</td>
# <td>$145.00</td>
# <td></td>
# <td>$4,059.26</td>
# </tr>
# </table>
#
#
# <!-- PageNumber: Page 1 of 2 -->
# <!-- PageBreak -->
#
#
# ## Transaction History (Continued)
#
#
# <table>
# <tr>
# <th>Date</th>
# <th>Description</th>
# <th>Withdrawals</th>
# <th>Deposits</th>
# <th>Balance</th>
# </tr>
# <tr>
# <td>06/12/2025</td>
# <td>Streaming Service</td>
# <td>$15.49</td>
# <td></td>
# <td>$4,043.77</td>
# </tr>
# <tr>
# <td>06/15/2025</td>
# <td>Transfer from Savings</td>
# <td></td>
# <td>$1,300.00</td>
# <td>$5,343.77</td>
# </tr>
# <tr>
# <td>06/18/2025</td>
# <td>Ride Service</td>
# <td>$25.00</td>
# <td></td>
# <td>$5,318.77</td>
# </tr>
# <tr>
# <td>06/22/2025</td>
# <td>Local Restaurant</td>
# <td>$80.00</td>
# <td></td>
# <td>$5,238.77</td>
# </tr>
# <tr>
# <td>06/25/2025</td>
# <td>Mobile Provider</td>
# <td>$110.00</td>
# <td></td>
# <td>$5,128.77</td>
# </tr>
# <tr>
# <td>06/28/2025</td>
# <td>Gas Station</td>
# <td>$53.77</td>
# <td></td>
# <td>$5,075.00</td>
# </tr>
# <tr>
# <td>06/30/2025</td>
# <td>Bank Service Fee</td>
# <td>$25.00</td>
# <td></td>
# <td>$5,050.00</td>
# </tr>
# </table>
#
#
# ## Notes
#
# For questions about this statement, please contact Contoso Bank Customer Service at (800) 555-
# 0123 or visit www.contosobank.com.
#
# This is a mock statement for design and testing purposes only. All data is fictitious.
#
# <!-- PageNumber: Page 2 of 2 -->
# <!-- PageBreak -->
#
#
# # Contoso Bank
#
#
# ## Loan Application Form
#
#
# ## 1. Applicant Information
#
#
# <table>
# <tr>
# <th>Full Name:</th>
# <th>John Smith</th>
# </tr>
# <tr>
# <th>Date of Birth:</th>
# <th>March 14, 1985</th>
# </tr>
# <tr>
# <th>SSN:</th>
# <th>123-45-6789</th>
# </tr>
# <tr>
# <th>Phone Number:</th>
# <th>(555) 123-4567</th>
# </tr>
# <tr>
# <th>Home Address:</th>
# <th>456 Maple Street, Springfield, IL 62704</th>
# </tr>
# </table>
#
#
# ## 2. Employment Information
#
# Employer:
# Contoso Technologies
#
# Job Title:
# Software Engineer
#
# Monthly Income (before tax):
# $6,500
#
# Employment Length:
# 5 years
#
#
# ## 3. Loan Details
#
# Loan Amount Requested:
# $25,000
#
# Purpose:
#
# Debt Consolidation
#
# Preferred Repayment Term:
# 36 months
#
#
# ## 4. Consent & Signature
#
# By submitting this application, I certify that all information is accurate and
# complete to the best of my knowledge. I authorize Contoso Bank to verify my
# credit history and employment status.
#
# Applicant Signature:
# John Smith
#
# Date:
# July 14, 2025

# %% [markdown]
# ## 6. Receipt Field Extraction with `prebuilt-receipt`
#
# Let's demonstrate using `prebuilt-receipt` to extract structured data from a receipt image. This analyzer automatically identifies merchant information, items, totals, taxes, and payment details without any configuration.

# %%
image_file = os.path.join(DOCS_DIR, "receipt.png")

# %%
img = Image.open(image_file)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1743x878>

# %%
analyzer_id = "prebuilt-receipt"

print(f"🔍 Analyzing '{image_file}' with '{analyzer_id}'...")

analysis_response = client.begin_analyze_binary(
    analyzer_id=analyzer_id,
    file_location=image_file,
)

print(f"⏳ Waiting for document analysis to complete...")
analysis_result = client.poll_result(analysis_response)
print(f"✅ Done")
# Out:
# 🔍 Analyzing 'documents/receipt.png' with 'prebuilt-receipt'...
# ⏳ Waiting for document analysis to complete...
# ✅ Done

# %%
print("\033[1;31;34m")
print(json.dumps(analysis_result, indent=5))
# Out:
# {
#      "id": "e2e168e1-e448-4bd8-9100-124663678816",
#      "status": "Succeeded",
#      "result": {
#           "analyzerId": "prebuilt-receipt",
#           "apiVersion": "2025-11-01",
#           "createdAt": "2026-02-11T13:31:09Z",
#           "stringEncoding": "codePoint",
#           "warnings": [],
#           "contents": [
#                {
#                     "path": "input1/segment1",
#                     "category": "receipt.generic",
#                     "markdown": "Contoso\n\n123 Main Street\nRedmond, WA 98052\n\n987-654-3210\n\n6/10/2019 13:59\nSales Associate: Paul\n\n2 Surface Pro 6\n\n$1,998.00\n\n3 Surface Pen\n\n$299.97\n\nSub-Total\n\n$2,297.97\n\nTax\n\n$218.31\n\nTotal\n\n$2,516.28\n",
#                     "fields": {
#                          "MerchantName": {
#                               "type": "string",
#                               "valueString": "Contoso",
#                               "spans": [
#                                    {
#                                         "offset": 0,
#                                         "length": 7
#                                    }
#                               ],
#                               "confidence": 0.616,
#                               "source": "D(1,775.0000,73.0000,973.0000,72.0000,973.0000,111.0000,775.0000,112.0000)"
#                          },
#                          "MerchantPhoneNumber": {
#                               "type": "string",
#                               "valueString": "987-654-3210",
#                               "spans": [
#                                    {
#                                         "offset": 44,
#                                         "length": 12
#                                    }
#                               ],
#                               "confidence": 0.872,
#                               "source": "D(1,700.0000,298.0000,842.0000,298.0000,842.0000,323.0000,700.0000,323.0000)"
#                          },
#                          "MerchantAddress": {
#                               "type": "string",
#                               "valueString": "123 Main Street Redmond, WA 98052",
#                               "spans": [
#                                    {
#                                         "offset": 9,
#                                         "length": 15
#                                    },
#                                    {
#                                         "offset": 25,
#                                         "length": 17
#                                    }
#                               ],
#                               "confidence": 0.872,
#                               "source": "D(1,700.0000,189.0000,859.0000,189.0000,859.0000,213.0000,700.0000,213.0000);D(1,699.8624,223.1231,911.0000,222.0000,911.1417,248.6482,700.0041,249.7713)"
#                          },
#                          "TotalAmount": {
#                               "type": "object",
#                               "valueObject": {
#                                    "CurrencyCode": {
#                                         "type": "string",
#                                         "valueString": "USD"
#                                    },
#                                    "Amount": {
#                                         "type": "number",
#                                         "valueNumber": 2516.28,
#                                         "spans": [
#                                              {
#                                                   "offset": 193,
#                                                   "length": 8
#                                              }
#                                         ],
#                                         "confidence": 0.816,
#                                         "source": "D(1,971.0000,710.0000,1054.0000,710.0000,1054.0000,737.0000,971.0000,737.0000)"
#                                    }
#                               }
#                          },
#                          "TransactionDate": {
#                               "type": "date",
#                               "valueDate": "2019-06-10",
#                               "spans": [
#                                    {
#                                         "offset": 58,
#                                         "length": 9
#                                    }
#                               ],
#                               "confidence": 0.822,
#                               "source": "D(1,699.0000,372.0000,794.0000,373.0000,794.0000,399.0000,699.0000,400.0000)"
#                          },
#                          "TransactionTime": {
#                               "type": "time",
#                               "valueTime": "13:59:00",
#                               "spans": [
#                                    {
#                                         "offset": 68,
#                                         "length": 5
#                                    }
#                               ],
#                               "confidence": 0.872,
#                               "source": "D(1,802.0000,373.0000,853.0000,373.0000,853.0000,399.0000,802.0000,399.0000)"
#                          },
#                          "SubtotalAmount": {
#                               "type": "object",
#                               "valueObject": {
#                                    "CurrencyCode": {
#                                         "type": "string",
#                                         "valueString": "USD"
#                                    },
#                                    "Amount": {
#                                         "type": "number",
#                                         "valueNumber": 2297.97
#                                    }
#                               }
#                          },
#                          "TotalTaxAmount": {
#                               "type": "object",
#                               "valueObject": {
#                                    "CurrencyCode": {
#                                         "type": "string",
#                                         "valueString": "USD"
#                                    },
#                                    "Amount": {
#                                         "type": "number",
#                                         "valueNumber": 218.31
#                                    }
#                               }
#                          },
#                          "TipAmount": {
#                               "type": "object",
#                               "valueObject": {
#                                    "CurrencyCode": {
#                                         "type": "string"
#                                    },
#                                    "Amount": {
#                                         "type": "number",
#                                         "confidence": 0.927
#                                    }
#                               }
#                          },
#                          "LineItems": {
#                               "type": "array",
#                               "valueArray": [
#                                    {
#                                         "type": "object",
#                                         "valueObject": {
#                                              "TotalAmount": {
#                                                   "type": "object",
#                                                   "valueObject": {
#                                                        "CurrencyCode": {
#                                                             "type": "string",
#                                                             "valueString": "USD"
#                                                        },
#                                                        "Amount": {
#                                                             "type": "number",
#                                                             "valueNumber": 1998,
#                                                             "spans": [
#                                                                  {
#                                                                       "offset": 114,
#                                                                       "length": 9
#                                                                  }
#                                                             ],
#                                                             "confidence": 0.78,
#                                                             "source": "D(1,952.0000,482.0000,1048.0000,482.0000,1048.0000,509.0000,952.0000,509.0000)"
#                                                        }
#                                                   }
#                                              },
#                                              "Description": {
#                                                   "type": "string",
#                                                   "valueString": "Surface Pro 6",
#                                                   "spans": [
#                                                        {
#                                                             "offset": 99,
#                                                             "length": 13
#                                                        }
#                                                   ],
#                                                   "confidence": 0.625,
#                                                   "source": "D(1,729.0000,483.0000,874.0000,483.0000,874.0000,508.0000,729.0000,508.0000)"
#                                              },
#                                              "Quantity": {
#                                                   "type": "number",
#                                                   "valueNumber": 2,
#                                                   "spans": [
#                                                        {
#                                                             "offset": 97,
#                                                             "length": 1
#                                                        }
#                                                   ],
#                                                   "confidence": 0.887,
#                                                   "source": "D(1,705.0000,483.0000,716.0000,483.0000,716.0000,508.0000,705.0000,508.0000)"
#                                              },
#                                              "UnitPrice": {
#                                                   "type": "object",
#                                                   "valueObject": {
#                                                        "CurrencyCode": {
#                                                             "type": "string"
#                                                        },
#                                                        "Amount": {
#                                                             "type": "number",
#                                                             "confidence": 0.983
#                                                        }
#                                                   }
#                                              },
#                                              "ProductCode": {
#                                                   "type": "string",
#                                                   "confidence": 0.979
#                                              },
#                                              "QuantityUnit": {
#                                                   "type": "string",
#                                                   "confidence": 0.968
#                                              }
#                                         }
#                                    },
#                                    {
#                                         "type": "object",
#                                         "valueObject": {
#                                              "TotalAmount": {
#                                                   "type": "object",
#                                                   "valueObject": {
#                                                        "CurrencyCode": {
#                                                             "type": "string",
#                                                             "valueString": "USD"
#                                                        },
#                                                        "Amount": {
#                                                             "type": "number",
#                                                             "valueNumber": 299.97,
#                                                             "spans": [
#                                                                  {
#                                                                       "offset": 140,
#                                                                       "length": 7
#                                                                  }
#                                                             ],
#                                                             "confidence": 0.877,
#                                                             "source": "D(1,969.0000,520.0000,1049.0000,520.0000,1049.0000,546.0000,969.0000,546.0000)"
#                                                        }
#                                                   }
#                                              },
#                                              "Description": {
#                                                   "type": "string",
#                                                   "valueString": "Surface Pen",
#                                                   "spans": [
#                                                        {
#                                                             "offset": 127,
#                                                             "length": 11
#                                                        }
#                                                   ],
#                                                   "confidence": 0.676,
#                                                   "source": "D(1,729.0000,522.0000,858.0000,522.0000,858.0000,546.0000,729.0000,546.0000)"
#                                              },
#                                              "Quantity": {
#                                                   "type": "number",
#                                                   "valueNumber": 3,
#                                                   "spans": [
#                                                        {
#                                                             "offset": 125,
#                                                             "length": 1
#                                                        }
#                                                   ],
#                                                   "confidence": 0.873,
#                                                   "source": "D(1,705.0000,523.0000,715.0000,523.0000,715.0000,547.0000,705.0000,547.0000)"
#                                              },
#                                              "UnitPrice": {
#                                                   "type": "object",
#                                                   "valueObject": {
#                                                        "CurrencyCode": {
#                                                             "type": "string"
#                                                        },
#                                                        "Amount": {
#                                                             "type": "number",
#                                                             "confidence": 0.983
#                                                        }
#                                                   }
#                                              },
#                                              "ProductCode": {
#                                                   "type": "string",
#                                                   "confidence": 0.979
#                                              },
#                                              "QuantityUnit": {
#                                                   "type": "string",
#                                                   "confidence": 0.968
#                                              }
#                                         }
#                                    }
#                               ]
#                          },
#                          "CountryRegion": {
#                               "type": "string",
#                               "valueString": "USA"
#                          },
#                          "TaxDetails": {
#                               "type": "array",
#                               "valueArray": [
#                                    {
#                                         "type": "object",
#                                         "valueObject": {
#                                              "Amount": {
#                                                   "type": "object",
#                                                   "valueObject": {
#                                                        "CurrencyCode": {
#                                                             "type": "string",
#                                                             "valueString": "USD"
#                                                        },
#                                                        "Amount": {
#                                                             "type": "number",
#                                                             "valueNumber": 218.31,
#                                                             "spans": [
#                                                                  {
#                                                                       "offset": 177,
#                                                                       "length": 6
#                                                                  }
#                                                             ],
#                                                             "confidence": 0.824,
#                                                             "source": "D(1,989.0000,634.0000,1050.0000,634.0000,1050.0000,660.0000,989.0000,660.0000)"
#                                                        }
#                                                   }
#                                              },
#                                              "Rate": {
#                                                   "type": "number",
#                                                   "confidence": 0.938
#                                              },
#                                              "NetAmount": {
#                                                   "type": "object",
#                                                   "valueObject": {
#                                                        "CurrencyCode": {
#                                                             "type": "string"
#                                                        },
#                                                        "Amount": {
#                                                             "type": "number",
#                                                             "confidence": 0.92
#                                                        }
#                                                   }
#                                              },
#                                              "Description": {
#                                                   "type": "string",
#                                                   "valueString": "Tax",
#                                                   "spans": [
#                                                        {
#                                                             "offset": 171,
#                                                             "length": 3
#                                                        }
#                                                   ],
#                                                   "confidence": 0.596,
#                                                   "source": "D(1,768.0000,635.0000,805.0000,636.0000,805.0000,659.0000,768.0000,658.0000)"
#                                              }
#                                         }
#                                    }
#                               ]
#                          }
#                     },
#                     "kind": "document",
#                     "startPageNumber": 1,
#                     "endPageNumber": 1,
#                     "unit": "pixel",
#                     "pages": [
#                          {
#                               "pageNumber": 1,
#                               "angle": -0.0049,
#                               "width": 1743,
#                               "height": 878,
#                               "spans": [
#                                    {
#                                         "offset": 0,
#                                         "length": 202
#                                    }
#                               ],
#                               "words": [
#                                    {
#                                         "content": "Contoso",
#                                         "span": {
#                                              "offset": 0,
#                                              "length": 7
#                                         },
#                                         "confidence": 0.995,
#                                         "source": "D(1,775,73,973,72,973,111,775,112)"
#                                    },
#                                    {
#                                         "content": "123",
#                                         "span": {
#                                              "offset": 9,
#                                              "length": 3
#                                         },
#                                         "confidence": 0.992,
#                                         "source": "D(1,700,189,729,189,729,213,700,213)"
#                                    },
#                                    {
#                                         "content": "Main",
#                                         "span": {
#                                              "offset": 13,
#                                              "length": 4
#                                         },
#                                         "confidence": 0.989,
#                                         "source": "D(1,737,189,784,189,784,212,737,212)"
#                                    },
#                                    {
#                                         "content": "Street",
#                                         "span": {
#                                              "offset": 18,
#                                              "length": 6
#                                         },
#                                         "confidence": 0.993,
#                                         "source": "D(1,792,189,859,189,859,212,792,212)"
#                                    },
#                                    {
#                                         "content": "Redmond",
#                                         "span": {
#                                              "offset": 25,
#                                              "length": 7
#                                         },
#                                         "confidence": 0.995,
#                                         "source": "D(1,700,225,794,224,794,249,700,249)"
#                                    },
#                                    {
#                                         "content": ",",
#                                         "span": {
#                                              "offset": 32,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.998,
#                                         "source": "D(1,795,224,800,224,800,249,795,249)"
#                                    },
#                                    {
#                                         "content": "WA",
#                                         "span": {
#                                              "offset": 34,
#                                              "length": 2
#                                         },
#                                         "confidence": 0.988,
#                                         "source": "D(1,806,224,839,223,839,249,806,249)"
#                                    },
#                                    {
#                                         "content": "98052",
#                                         "span": {
#                                              "offset": 37,
#                                              "length": 5
#                                         },
#                                         "confidence": 0.978,
#                                         "source": "D(1,845,223,911,222,911,248,845,249)"
#                                    },
#                                    {
#                                         "content": "987-654-3210",
#                                         "span": {
#                                              "offset": 44,
#                                              "length": 12
#                                         },
#                                         "confidence": 0.967,
#                                         "source": "D(1,700,298,842,298,842,323,700,323)"
#                                    },
#                                    {
#                                         "content": "6/10/2019",
#                                         "span": {
#                                              "offset": 58,
#                                              "length": 9
#                                         },
#                                         "confidence": 0.987,
#                                         "source": "D(1,699,372,794,373,794,399,699,400)"
#                                    },
#                                    {
#                                         "content": "13",
#                                         "span": {
#                                              "offset": 68,
#                                              "length": 2
#                                         },
#                                         "confidence": 0.997,
#                                         "source": "D(1,802,373,821,373,821,399,802,399)"
#                                    },
#                                    {
#                                         "content": ":",
#                                         "span": {
#                                              "offset": 70,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.999,
#                                         "source": "D(1,822,373,826,373,826,399,822,399)"
#                                    },
#                                    {
#                                         "content": "59",
#                                         "span": {
#                                              "offset": 71,
#                                              "length": 2
#                                         },
#                                         "confidence": 0.997,
#                                         "source": "D(1,827,373,853,373,853,399,827,399)"
#                                    },
#                                    {
#                                         "content": "Sales",
#                                         "span": {
#                                              "offset": 74,
#                                              "length": 5
#                                         },
#                                         "confidence": 0.998,
#                                         "source": "D(1,700,409,756,410,756,433,700,433)"
#                                    },
#                                    {
#                                         "content": "Associate",
#                                         "span": {
#                                              "offset": 80,
#                                              "length": 9
#                                         },
#                                         "confidence": 0.997,
#                                         "source": "D(1,762,410,863,410,863,433,762,433)"
#                                    },
#                                    {
#                                         "content": ":",
#                                         "span": {
#                                              "offset": 89,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.999,
#                                         "source": "D(1,864,410,869,410,869,433,864,433)"
#                                    },
#                                    {
#                                         "content": "Paul",
#                                         "span": {
#                                              "offset": 91,
#                                              "length": 4
#                                         },
#                                         "confidence": 0.998,
#                                         "source": "D(1,876,410,923,409,923,433,876,433)"
#                                    },
#                                    {
#                                         "content": "2",
#                                         "span": {
#                                              "offset": 97,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.998,
#                                         "source": "D(1,705,483,716,483,716,508,705,508)"
#                                    },
#                                    {
#                                         "content": "Surface",
#                                         "span": {
#                                              "offset": 99,
#                                              "length": 7
#                                         },
#                                         "confidence": 0.995,
#                                         "source": "D(1,729,483,811,483,811,508,729,508)"
#                                    },
#                                    {
#                                         "content": "Pro",
#                                         "span": {
#                                              "offset": 107,
#                                              "length": 3
#                                         },
#                                         "confidence": 0.991,
#                                         "source": "D(1,819,483,855,483,855,507,819,507)"
#                                    },
#                                    {
#                                         "content": "6",
#                                         "span": {
#                                              "offset": 111,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.986,
#                                         "source": "D(1,861,483,874,483,874,507,861,507)"
#                                    },
#                                    {
#                                         "content": "$",
#                                         "span": {
#                                              "offset": 114,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.999,
#                                         "source": "D(1,952,482,963,482,963,509,952,509)"
#                                    },
#                                    {
#                                         "content": "1,998.00",
#                                         "span": {
#                                              "offset": 115,
#                                              "length": 8
#                                         },
#                                         "confidence": 0.968,
#                                         "source": "D(1,964,482,1048,482,1048,509,964,509)"
#                                    },
#                                    {
#                                         "content": "3",
#                                         "span": {
#                                              "offset": 125,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.998,
#                                         "source": "D(1,705,523,715,523,715,547,705,547)"
#                                    },
#                                    {
#                                         "content": "Surface",
#                                         "span": {
#                                              "offset": 127,
#                                              "length": 7
#                                         },
#                                         "confidence": 0.992,
#                                         "source": "D(1,729,522,812,522,812,546,729,546)"
#                                    },
#                                    {
#                                         "content": "Pen",
#                                         "span": {
#                                              "offset": 135,
#                                              "length": 3
#                                         },
#                                         "confidence": 0.996,
#                                         "source": "D(1,819,522,858,522,858,546,819,546)"
#                                    },
#                                    {
#                                         "content": "$",
#                                         "span": {
#                                              "offset": 140,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.997,
#                                         "source": "D(1,969,520,980,520,980,546,969,546)"
#                                    },
#                                    {
#                                         "content": "299.97",
#                                         "span": {
#                                              "offset": 141,
#                                              "length": 6
#                                         },
#                                         "confidence": 0.969,
#                                         "source": "D(1,981,520,1049,520,1049,546,981,546)"
#                                    },
#                                    {
#                                         "content": "Sub",
#                                         "span": {
#                                              "offset": 149,
#                                              "length": 3
#                                         },
#                                         "confidence": 0.992,
#                                         "source": "D(1,764,598,804,597,804,621,764,622)"
#                                    },
#                                    {
#                                         "content": "-",
#                                         "span": {
#                                              "offset": 152,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.998,
#                                         "source": "D(1,804,597,813,597,813,621,804,621)"
#                                    },
#                                    {
#                                         "content": "Total",
#                                         "span": {
#                                              "offset": 153,
#                                              "length": 5
#                                         },
#                                         "confidence": 0.971,
#                                         "source": "D(1,814,597,868,597,868,621,814,621)"
#                                    },
#                                    {
#                                         "content": "$",
#                                         "span": {
#                                              "offset": 160,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.998,
#                                         "source": "D(1,952,597,963,597,963,623,952,623)"
#                                    },
#                                    {
#                                         "content": "2,297.97",
#                                         "span": {
#                                              "offset": 161,
#                                              "length": 8
#                                         },
#                                         "confidence": 0.955,
#                                         "source": "D(1,965,597,1050,597,1050,622,965,623)"
#                                    },
#                                    {
#                                         "content": "Tax",
#                                         "span": {
#                                              "offset": 171,
#                                              "length": 3
#                                         },
#                                         "confidence": 0.961,
#                                         "source": "D(1,768,635,805,636,805,659,768,658)"
#                                    },
#                                    {
#                                         "content": "$",
#                                         "span": {
#                                              "offset": 176,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.999,
#                                         "source": "D(1,976,634,987,634,987,660,976,660)"
#                                    },
#                                    {
#                                         "content": "218.31",
#                                         "span": {
#                                              "offset": 177,
#                                              "length": 6
#                                         },
#                                         "confidence": 0.987,
#                                         "source": "D(1,989,634,1050,634,1050,660,989,660)"
#                                    },
#                                    {
#                                         "content": "Total",
#                                         "span": {
#                                              "offset": 185,
#                                              "length": 5
#                                         },
#                                         "confidence": 0.997,
#                                         "source": "D(1,769,712,822,712,822,736,769,737)"
#                                    },
#                                    {
#                                         "content": "$",
#                                         "span": {
#                                              "offset": 192,
#                                              "length": 1
#                                         },
#                                         "confidence": 0.998,
#                                         "source": "D(1,959,710,970,710,970,737,959,737)"
#                                    },
#                                    {
#                                         "content": "2,516.28",
#                                         "span": {
#                                              "offset": 193,
#                                              "length": 8
#                                         },
#                                         "confidence": 0.944,
#                                         "source": "D(1,971,710,1054,710,1054,737,971,737)"
#                                    }
#                               ],
#                               "lines": [
#                                    {
#                                         "content": "Contoso",
#                                         "source": "D(1,775,73,973,72,973,111,775,112)",
#                                         "span": {
#                                              "offset": 0,
#                                              "length": 7
#                                         }
#                                    },
#                                    {
#                                         "content": "123 Main Street",
#                                         "source": "D(1,700,189,859,188,859,212,700,213)",
#                                         "span": {
#                                              "offset": 9,
#                                              "length": 15
#                                         }
#                                    },
#                                    {
#                                         "content": "Redmond, WA 98052",
#                                         "source": "D(1,700,225,911,222,911,248,700,250)",
#                                         "span": {
#                                              "offset": 25,
#                                              "length": 17
#                                         }
#                                    },
#                                    {
#                                         "content": "987-654-3210",
#                                         "source": "D(1,700,298,842,298,842,323,700,323)",
#                                         "span": {
#                                              "offset": 44,
#                                              "length": 12
#                                         }
#                                    },
#                                    {
#                                         "content": "6/10/2019 13:59",
#                                         "source": "D(1,699,372,853,372,853,400,699,400)",
#                                         "span": {
#                                              "offset": 58,
#                                              "length": 15
#                                         }
#                                    },
#                                    {
#                                         "content": "Sales Associate: Paul",
#                                         "source": "D(1,700,409,923,409,923,433,700,433)",
#                                         "span": {
#                                              "offset": 74,
#                                              "length": 21
#                                         }
#                                    },
#                                    {
#                                         "content": "2 Surface Pro 6",
#                                         "source": "D(1,705,483,874,482,874,507,705,508)",
#                                         "span": {
#                                              "offset": 97,
#                                              "length": 15
#                                         }
#                                    },
#                                    {
#                                         "content": "$1,998.00",
#                                         "source": "D(1,952,482,1048,482,1048,509,952,509)",
#                                         "span": {
#                                              "offset": 114,
#                                              "length": 9
#                                         }
#                                    },
#                                    {
#                                         "content": "3 Surface Pen",
#                                         "source": "D(1,705,522,858,522,858,546,705,547)",
#                                         "span": {
#                                              "offset": 125,
#                                              "length": 13
#                                         }
#                                    },
#                                    {
#                                         "content": "$299.97",
#                                         "source": "D(1,969,520,1049,520,1049,546,969,546)",
#                                         "span": {
#                                              "offset": 140,
#                                              "length": 7
#                                         }
#                                    },
#                                    {
#                                         "content": "Sub-Total",
#                                         "source": "D(1,764,598,868,597,868,621,764,622)",
#                                         "span": {
#                                              "offset": 149,
#                                              "length": 9
#                                         }
#                                    },
#                                    {
#                                         "content": "$2,297.97",
#                                         "source": "D(1,952,597,1050,597,1050,623,952,623)",
#                                         "span": {
#                                              "offset": 160,
#                                              "length": 9
#                                         }
#                                    },
#                                    {
#                                         "content": "Tax",
#                                         "source": "D(1,768,635,805,636,805,659,767,658)",
#                                         "span": {
#                                              "offset": 171,
#                                              "length": 3
#                                         }
#                                    },
#                                    {
#                                         "content": "$218.31",
#                                         "source": "D(1,976,634,1050,634,1050,660,976,660)",
#                                         "span": {
#                                              "offset": 176,
#                                              "length": 7
#                                         }
#                                    },
#                                    {
#                                         "content": "Total",
#                                         "source": "D(1,769,712,822,712,822,737,768,737)",
#                                         "span": {
#                                              "offset": 185,
#                                              "length": 5
#                                         }
#                                    },
#                                    {
#                                         "content": "$2,516.28",
#                                         "source": "D(1,959,710,1054,710,1055,737,959,737)",
#                                         "span": {
#                                              "offset": 192,
#                                              "length": 9
#                                         }
#                                    }
#                               ]
#                          }
#                     ],
#                     "paragraphs": [
#                          {
#                               "content": "Contoso",
#                               "source": "D(1,775,73,973,72,973,111,775,112)",
#                               "span": {
#                                    "offset": 0,
#                                    "length": 7
#                               }
#                          },
#                          {
#                               "content": "123 Main Street Redmond, WA 98052",
#                               "source": "D(1,700,189,910,187,911,248,700,250)",
#                               "span": {
#                                    "offset": 9,
#                                    "length": 33
#                               }
#                          },
#                          {
#                               "content": "987-654-3210",
#                               "source": "D(1,700,298,842,298,842,323,700,323)",
#                               "span": {
#                                    "offset": 44,
#                                    "length": 12
#                               }
#                          },
#                          {
#                               "content": "6/10/2019 13:59 Sales Associate: Paul",
#                               "source": "D(1,699,372,923,372,923,433,699,433)",
#                               "span": {
#                                    "offset": 58,
#                                    "length": 37
#                               }
#                          },
#                          {
#                               "content": "2 Surface Pro 6",
#                               "source": "D(1,705,483,874,482,874,507,705,508)",
#                               "span": {
#                                    "offset": 97,
#                                    "length": 15
#                               }
#                          },
#                          {
#                               "content": "$1,998.00",
#                               "source": "D(1,952,482,1048,482,1048,509,952,509)",
#                               "span": {
#                                    "offset": 114,
#                                    "length": 9
#                               }
#                          },
#                          {
#                               "content": "3 Surface Pen",
#                               "source": "D(1,705,522,858,522,858,546,705,547)",
#                               "span": {
#                                    "offset": 125,
#                                    "length": 13
#                               }
#                          },
#                          {
#                               "content": "$299.97",
#                               "source": "D(1,969,520,1049,520,1049,546,969,546)",
#                               "span": {
#                                    "offset": 140,
#                                    "length": 7
#                               }
#                          },
#                          {
#                               "content": "Sub-Total",
#                               "source": "D(1,764,598,868,597,868,621,764,622)",
#                               "span": {
#                                    "offset": 149,
#                                    "length": 9
#                               }
#                          },
#                          {
#                               "content": "$2,297.97",
#                               "source": "D(1,952,597,1050,597,1050,623,952,623)",
#                               "span": {
#                                    "offset": 160,
#                                    "length": 9
#                               }
#                          },
#                          {
#                               "content": "Tax",
#                               "source": "D(1,768,635,805,636,805,659,767,658)",
#                               "span": {
#                                    "offset": 171,
#                                    "length": 3
#                               }
#                          },
#                          {
#                               "content": "$218.31",
#                               "source": "D(1,976,634,1050,634,1050,660,976,660)",
#                               "span": {
#                                    "offset": 176,
#                                    "length": 7
#                               }
#                          },
#                          {
#                               "content": "Total",
#                               "source": "D(1,769,712,822,712,822,737,768,737)",
#                               "span": {
#                                    "offset": 185,
#                                    "length": 5
#                               }
#                          },
#                          {
#                               "content": "$2,516.28",
#                               "source": "D(1,959,710,1054,710,1055,737,959,737)",
#                               "span": {
#                                    "offset": 192,
#                                    "length": 9
#                               }
#                          }
#                     ],
#                     "analyzerId": "prebuilt-receipt.generic",
#                     "mimeType": "image/png"
#                }
#           ]
#      },
#      "usage": {
#           "documentPagesStandard": 1,
#           "contextualizationTokens": 1000,
#           "tokens": {
#                "gpt-4.1-input": 6905,
#                "gpt-4.1-output": 601,
#                "text-embedding-3-large": 86
#           }
#      }
# }

# %%
print("\033[1;31;34m")
print(analysis_result['result']['contents'][0]['markdown'])
# Out:
# Contoso
#
# 123 Main Street
# Redmond, WA 98052
#
# 987-654-3210
#
# 6/10/2019 13:59
# Sales Associate: Paul
#
# 2 Surface Pro 6
#
# $1,998.00
#
# 3 Surface Pen
#
# $299.97
#
# Sub-Total
#
# $2,297.97
#
# Tax
#
# $218.31
#
# Total
#
# $2,516.28

# %%
def print_section_header(title: str, char: str = "=") -> None:
    """Print a formatted section header"""
    print(f"\n{char * 70}")
    print(f"{title.center(70)}")
    print(f"{char * 70}\n")


def print_subsection(title: str) -> None:
    """Print a formatted subsection header"""
    print(f"\n--- {title} ---")


def format_currency(amount: float, currency: str = "USD") -> str:
    """Format currency amount"""
    symbols = {"USD": "$", "EUR": "€", "GBP": "£"}
    symbol = symbols.get(currency, currency)
    return f"{symbol}{amount:,.2f}"


def display_receipt_analysis(data: Dict[str, Any]) -> None:
    """Display receipt analysis results in a formatted way"""

    # Document status
    print_section_header("📋 DOCUMENT ANALYSIS SUMMARY", "=")
    print(f"Status:           ✅ {data['status']}")
    print(f"Document ID:      {data['id']}")

    result = data['result']
    print(f"Analyzer:         {result['analyzerId']}")
    print(f"API Version:      {result['apiVersion']}")
    print(f"Created:          {result['createdAt']}")

    # Get the first content (receipt)
    content = result['contents'][0]
    fields = content['fields']

    # Merchant Information
    print_section_header("🏪 MERCHANT INFORMATION")

    if 'MerchantName' in fields:
        merchant = fields['MerchantName']
        print(f"Name:             {merchant['valueString']}")
        print(f"                  (confidence: {merchant['confidence']:.1%})")

    if 'MerchantAddress' in fields:
        address = fields['MerchantAddress']
        print(f"Address:          {address['valueString']}")
        print(f"                  (confidence: {address['confidence']:.1%})")

    if 'MerchantPhoneNumber' in fields:
        phone = fields['MerchantPhoneNumber']
        print(f"Phone:            {phone['valueString']}")
        print(f"                  (confidence: {phone['confidence']:.1%})")

    if 'CountryRegion' in fields:
        print(f"Country:          {fields['CountryRegion']['valueString']}")

    # Transaction Information
    print_section_header("📅 TRANSACTION INFORMATION")

    if 'TransactionDate' in fields:
        date_str = fields['TransactionDate']['valueDate']
        date_obj = datetime.fromisoformat(date_str)
        print(f"Date:             {date_obj.strftime('%B %d, %Y')}")
        print(
            f"                  (confidence: {fields['TransactionDate']['confidence']:.1%})"
        )

    if 'TransactionTime' in fields:
        time_str = fields['TransactionTime']['valueTime']
        print(f"Time:             {time_str}")
        print(
            f"                  (confidence: {fields['TransactionTime']['confidence']:.1%})"
        )

    # Line Items
    print_section_header("🛒 ITEMS PURCHASED")

    if 'LineItems' in fields:
        items = fields['LineItems']['valueArray']

        for idx, item in enumerate(items, 1):
            item_obj = item['valueObject']
            print_subsection(f"Item {idx}")

            if 'Description' in item_obj:
                desc = item_obj['Description']
                print(f"  Product:        {desc['valueString']}")
                print(
                    f"                  (confidence: {desc['confidence']:.1%})"
                )

            if 'Quantity' in item_obj:
                qty = item_obj['Quantity']
                print(f"  Quantity:       {int(qty['valueNumber'])}")
                print(
                    f"                  (confidence: {qty['confidence']:.1%})")

            if 'TotalAmount' in item_obj:
                total = item_obj['TotalAmount']['valueObject']
                amount = total['Amount']['valueNumber']
                currency = total['CurrencyCode']['valueString']
                confidence = total['Amount']['confidence']
                print(f"  Total:          {format_currency(amount, currency)}")
                print(f"                  (confidence: {confidence:.1%})")

    # Payment Summary
    print_section_header("💰 PAYMENT SUMMARY")

    # Create summary table
    print(f"{'Description':<20} {'Amount':>15} {'Confidence':>15}")
    print("-" * 50)

    if 'SubtotalAmount' in fields:
        subtotal = fields['SubtotalAmount']['valueObject']
        amount = subtotal['Amount']['valueNumber']
        currency = subtotal['CurrencyCode']['valueString']
        print(f"{'Subtotal':<20} {format_currency(amount, currency):>15}")

    if 'TotalTaxAmount' in fields:
        tax = fields['TotalTaxAmount']['valueObject']
        amount = tax['Amount']['valueNumber']
        currency = tax['CurrencyCode']['valueString']
        print(f"{'Tax':<20} {format_currency(amount, currency):>15}")

    print("-" * 50)

    if 'TotalAmount' in fields:
        total = fields['TotalAmount']['valueObject']
        amount = total['Amount']['valueNumber']
        currency = total['CurrencyCode']['valueString']
        confidence = total['Amount']['confidence']
        print(
            f"{'TOTAL':<20} {format_currency(amount, currency):>15} {confidence:>14.1%}"
        )

    # Tax Details
    if 'TaxDetails' in fields:
        print_subsection("Tax Breakdown")
        tax_details = fields['TaxDetails']['valueArray']
        for tax_item in tax_details:
            tax_obj = tax_item['valueObject']
            if 'Amount' in tax_obj:
                tax_amount = tax_obj['Amount']['valueObject']
                amount = tax_amount['Amount']['valueNumber']
                currency = tax_amount['CurrencyCode']['valueString']
                confidence = tax_amount['Amount']['confidence']
                print(f"  Tax Amount:     {format_currency(amount, currency)}")
                print(f"                  (confidence: {confidence:.1%})")

    # Page Information
    print_section_header("📄 PAGE INFORMATION")

    page = content['pages'][0]
    print(f"Page Number:      {page['pageNumber']}")
    print(f"Dimensions:       {page['width']} x {page['height']} pixels")
    print(f"Angle:            {page['angle']:.4f}°")
    print(f"Words Extracted:  {len(page.get('words', []))}")
    if 'lines' in page:
        print(f"Lines Extracted:  {len(page['lines'])}")

    # Usage Statistics
    print_section_header("📊 USAGE STATISTICS")

    usage = data['usage']
    print(
        f"Pages Processed:  {usage['documentPagesStandard']} standard page(s)")
    print(f"Context Tokens:   {usage['contextualizationTokens']:,}")

    if 'tokens' in usage:
        tokens = usage['tokens']
        print("\nAI Model Tokens:")
        for model, count in tokens.items():
            print(f"  {model:<25} {count:>10,}")

    # Raw Receipt Text
    print_section_header("📝 EXTRACTED TEXT (RAW)")
    print(content['markdown'])

# %%
display_receipt_analysis(analysis_result)
# Out:
# ======================================================================
#                      📋 DOCUMENT ANALYSIS SUMMARY
# ======================================================================
#
# Status:           ✅ Succeeded
# Document ID:      e2e168e1-e448-4bd8-9100-124663678816
# Analyzer:         prebuilt-receipt
# API Version:      2025-11-01
# Created:          2026-02-11T13:31:09Z
#
# ======================================================================
#                         🏪 MERCHANT INFORMATION
# ======================================================================
#
# Name:             Contoso
#                   (confidence: 61.6%)
# Address:          123 Main Street Redmond, WA 98052
#                   (confidence: 87.2%)
# Phone:            987-654-3210
#                   (confidence: 87.2%)
# Country:          USA
#
# ======================================================================
#                       📅 TRANSACTION INFORMATION
# ======================================================================
#
# Date:             June 10, 2019
#                   (confidence: 82.2%)
# Time:             13:59:00
#                   (confidence: 87.2%)
#
# ======================================================================
#                           🛒 ITEMS PURCHASED
# ======================================================================
#
#
# --- Item 1 ---
#   Product:        Surface Pro 6
#                   (confidence: 62.5%)
#   Quantity:       2
#                   (confidence: 88.7%)
#   Total:          $1,998.00
#                   (confidence: 78.0%)
#
# --- Item 2 ---
#   Product:        Surface Pen
#                   (confidence: 67.6%)
#   Quantity:       3
#                   (confidence: 87.3%)
#   Total:          $299.97
#                   (confidence: 87.7%)
#
# ======================================================================
#                           💰 PAYMENT SUMMARY
# ======================================================================
#
# Description                   Amount      Confidence
# --------------------------------------------------
# Subtotal                   $2,297.97
# Tax                          $218.31
# --------------------------------------------------
# TOTAL                      $2,516.28          81.6%
#
# --- Tax Breakdown ---
#   Tax Amount:     $218.31
#                   (confidence: 82.4%)
#
# ======================================================================
#                           📄 PAGE INFORMATION
# ======================================================================
#
# Page Number:      1
# Dimensions:       1743 x 878 pixels
# Angle:            -0.0049°
# Words Extracted:  39
# Lines Extracted:  16
#
# ======================================================================
#                           📊 USAGE STATISTICS
# ======================================================================
#
# Pages Processed:  1 standard page(s)
# Context Tokens:   1,000
#
# AI Model Tokens:
#   gpt-4.1-input                  6,905
#   gpt-4.1-output                   601
#   text-embedding-3-large            86
#
# ======================================================================
#                         📝 EXTRACTED TEXT (RAW)
# ======================================================================
#
# Contoso
#
# 123 Main Street
# Redmond, WA 98052
#
# 987-654-3210
#
# 6/10/2019 13:59
# Sales Associate: Paul
#
# 2 Surface Pro 6
#
# $1,998.00
#
# 3 Surface Pen
#
# $299.97
#
# Sub-Total
#
# $2,297.97
#
# Tax
#
# $218.31
#
# Total
#
# $2,516.28

# %%
saved_file_path = save_json_to_file(analysis_result, filename_prefix="prebuilt_receipt_analysis_result")
# Out:
# 💾 Analysis result saved to: results/prebuilt_receipt_analysis_result_20260211_133128.json

# %%
# !ls $saved_file_path -lh
# Out:
# -rwxrwxrwx 1 root root 30K Feb 11 13:31 results/prebuilt_receipt_analysis_result_20260211_133128.json

# %% [markdown]
# ## 7. Using `prebuilt-invoice`

# %%
document_file = os.path.join(DOCS_DIR, "invoice.pdf")
# !ls $document_file -lh
# Out:
# -rwxrwxrwx 1 root root 148K Dec  2 13:20 documents/invoice.pdf

# %%
analyzer_id = "prebuilt-invoice"

print(f"🔍 Analyzing '{document_file}' with '{analyzer_id}'...")

analysis_response = client.begin_analyze_binary(
    analyzer_id=analyzer_id,
    file_location=document_file,
)

print(f"⏳ Waiting for document analysis to complete...")
analysis_result = client.poll_result(analysis_response)
print(f"✅ Done")
# Out:
# 🔍 Analyzing 'documents/invoice.pdf' with 'prebuilt-invoice'...
# ⏳ Waiting for document analysis to complete...
# ✅ Done

# %%
print("\033[1;31;34m")
print(json.dumps(analysis_result, indent=5))
# Out:
# {
#      "id": "24201c38-3d1e-4c27-8efa-6f58cceabd64",
#      "status": "Succeeded",
#      "result": {
#           "analyzerId": "prebuilt-invoice",
#           "apiVersion": "2025-11-01",
#           "createdAt": "2026-02-11T13:31:29Z",
#           "stringEncoding": "codePoint",
#           "warnings": [],
#           "contents": [
#                {
#                     "path": "input1",
#                     "markdown": "CONTOSO LTD.\n\n\n# INVOICE\n\nContoso Headquarters\n123 456th St\nNew York, NY, 10001\n\nINVOICE: INV-100\n\nINVOICE DATE: 11/15/2019\n\nDUE DATE: 12/15/2019\n\nCUSTOMER NAME: MICROSOFT CORPORATION\n\nSERVICE PERIOD: 10/14/2019 - 11/14/2019\n\nCUSTOMER ID: CID-12345\n\nMicrosoft Corp\n123 Other St,\nRedmond WA, 98052\n\nBILL TO:\nMicrosoft Finance\n123 Bill St,\nRedmond WA, 98052\n\nSHIP TO:\nMicrosoft Delivery\n123 Ship St,\nRedmond WA, 98052\n\nSERVICE ADDRESS:\nMicrosoft Services\n123 Service St,\nRedmond WA, 98052\n\n\n<table>\n<tr>\n<th>SALESPERSON</th>\n<th>P.O. NUMBER</th>\n<th>REQUISITIONER</th>\n<th>SHIPPED VIA</th>\n<th>F.O.B. POINT</th>\n<th>TERMS</th>\n</tr>\n<tr>\n<td></td>\n<td>PO-3333</td>\n<td></td>\n<td></td>\n<td></td>\n<td></td>\n</tr>\n</table>\n\n\n<table>\n<tr>\n<th>DATE</th>\n<th>ITEM CODE</th>\n<th>DESCRIPTION</th>\n<th>QTY</th>\n<th>UM</th>\n<th>PRICE</th>\n<th>TAX</th>\n<th>AMOUNT</th>\n</tr>\n<tr>\n<td>3/4/2021</td>\n<td>A123</td>\n<td>Consulting Services</td>\n<td>2</td>\n<td>hours</td>\n<td>$30.00</td>\n<td>$6.00</td>\n<td>$60.00</td>\n</tr>\n<tr>\n<td>3/5/2021</td>\n<td>B456</td>\n<td>Document Fee</td>\n<td>3</td>\n<td></td>\n<td>$10.00</td>\n<td>$3.00</td>\n<td>$30.00</td>\n</tr>\n<tr>\n<td>3/6/2021</td>\n<td>C789</td>\n<td>Printing Fee</td>\n<td>10</td>\n<td>pages</td>\n<td>$1.00</td>\n<td>$1.00</td>\n<td>$10.00</td>\n</tr>\n</table>\n\n\n<table>\n<tr>\n<th>SUBTOTAL</th>\n<th>$100.00</th>\n</tr>\n<tr>\n<th>SALES TAX</th>\n<th>$10.00</th>\n</tr>\n<tr>\n<th>TOTAL</th>\n<th>$110.00</th>\n</tr>\n<tr>\n<th>PREVIOUS UNPAID BALANCE</th>\n<th>$500.00</th>\n</tr>\n<tr>\n<th>AMOUNT DUE</th>\n<th>$610.00</th>\n</tr>\n</table>\n\n\nTHANK YOU FOR YOUR BUSINESS!\n\nREMIT TO:\nContoso Billing\n123 Remit St\nNew York, NY, 10001\n",
#                     "fields": {
#                          "AmountDue": {
#                               "type": "object",
#                               "valueObject": {
#                                    "Amount": {
#                                         "type": "number",
#                                         "valueNumber": 610,
#                                         "spans": [
#                                              {
#                                                   "offset": 1522,
#                                                   "length": 7
#                                              }
#                                         ],
#                                         "confidence": 0.818,
#                                         "source": "D(1,7.3628,8.0513,7.9272,8.0513,7.9272,8.2124,7.3628,8.2124)"
#                                    },
#                                    "CurrencyCode": {
#                                         "type": "string",
#                                         "valueString": "USD"
#                                    }
#                               }
#                          },
#                          "BalanceForward": {
#                               "type": "object",
#                               "valueObject": {
#                                    "Amount": {
#                                         "type": "number",
#                                         "valueNumber": 500,
#                                         "spans": [
#                                              {
#                                                   "offset": 1474,
#                                                   "length": 7
#                                              }
#                                         ],
#                                         "confidence": 0.901,
#                                         "source": "D(1,7.3628,7.7458,7.9272,7.7458,7.9272,7.9089,7.3628,7.9089)"
#                                    },
#                                    "CurrencyCode": {
#                                         "type": "string",
#                                         "valueString": "USD"
#                                    }
#                               }
#                          },
#                          "BillingAddress": {
#                               "type": "string",
#                               "valueString": "123 Bill St, Redmond WA, 98052",
#                               "spans": [
#                                    {
#                                         "offset": 325,
#                                         "length": 12
#                                    },
#                                    {
#                                         "offset": 338,
#                                         "length": 17
#                                    }
#                               ],
#                               "confidence": 0.697,
#                               "source": "D(1,0.5801,3.9488,1.2845,3.9470,1.2849,4.1131,0.5805,4.1148);D(1,0.5717,4.1489,2.0244,4.1489,2.0244,4.3164,0.5717,4.3164)"
#                          },
#                          "BillingAddressRecipient": {
#                               "type": "string",
#                               "valueString": "Microsoft Finance",
#                               "spans": [
#                                    {
#                                         "offset": 307,
#                                         "length": 17
#                                    }
#                               ],
#                               "confidence": 0.739,
#                               "source": "D(1,0.5764,3.7506,1.8028,3.7549,1.8023,3.9115,0.5759,3.9072)"
#                          },
#                          "CountryRegion": {
#                               "type": "string",
#                               "valueString": "USA"
#                          },
#                          "CustomerAddress": {
#                               "type": "string",
#                               "valueString": "123 Other St, Redmond WA, 98052",
#                               "spans": [
#                                    {
#                                         "offset": 265,
#                                         "length": 13
#                                    },
#                                    {
#                                         "offset": 279,
#                                         "length": 17
#                                    }
#                               ],
#                               "confidence": 0.753,
#                               "source": "D(1,0.5795,2.8290,1.4756,2.8358,1.4744,2.9990,0.5783,2.9922);D(1,0.5721,3.0330,2.0244,3.0318,2.0245,3.1984,0.5722,3.1996)"
#                          },
#                          "CustomerAddressRecipient": {
#                               "type": "string",
#                               "valueString": "Microsoft Corp",
#                               "spans": [
#                                    {
#                                         "offset": 250,
#                                         "length": 14
#                                    }
#                               ],
#                               "confidence": 0.458,
#                               "source": "D(1,0.5736,2.6263,1.5979,2.6278,1.5976,2.8016,0.5733,2.8001)"
#                          },
#                          "CustomerId": {
#                               "type": "string",
#                               "valueString": "CID-12345",
#                               "spans": [
#                                    {
#                                         "offset": 239,
#                                         "length": 9
#                                    }
#                               ],
#                               "confidence": 0.901,
#                               "source": "D(1,7.3232,2.4188,8.0103,2.4190,8.0103,2.5713,7.3232,2.5711)"
#                          },
#                          "CustomerName": {
#                               "type": "string",
#                               "valueString": "MICROSOFT CORPORATION",
#                               "spans": [
#                                    {
#                                         "offset": 162,
#                                         "length": 21
#                                    }
#                               ],
#                               "confidence": 0.232,
#                               "source": "D(1,6.2250,2.0092,8.0020,2.0077,8.0021,2.1638,6.2251,2.1653)"
#                          },
#                          "CustomerTaxId": {
#                               "type": "string",
#                               "confidence": 0.912
#                          },
#                          "DueDate": {
#                               "type": "date",
#                               "valueDate": "2019-12-15",
#                               "spans": [
#                                    {
#                                         "offset": 135,
#                                         "length": 10
#                                    }
#                               ],
#                               "confidence": 0.949,
#                               "source": "D(1,7.2352,1.8078,8.0061,1.8064,8.0061,1.9641,7.2352,1.9655)"
#                          },
#                          "InvoiceDate": {
#                               "type": "date",
#                               "valueDate": "2019-11-15",
#                               "spans": [
#                                    {
#                                         "offset": 113,
#                                         "length": 10
#                                    }
#                               ],
#                               "confidence": 0.872,
#                               "source": "D(1,7.2399,1.5954,8.0061,1.5908,8.0061,1.7482,7.2398,1.7526)"
#                          },
#                          "InvoiceId": {
#                               "type": "string",
#                               "valueString": "INV-100",
#                               "spans": [
#                                    {
#                                         "offset": 90,
#                                         "length": 7
#                                    }
#                               ],
#                               "confidence": 0.699,
#                               "source": "D(1,7.4771,1.3992,8.0103,1.3980,8.0106,1.5464,7.4774,1.5476)"
#                          },
#                          "LineItems": {
#                               "type": "array",
#                               "valueArray": [
#                                    {
#                                         "type": "object",
#                                         "valueObject": {
#                                              "Date": {
#                                                   "type": "date",
#                                                   "valueDate": "2021-03-04",
#                                                   "spans": [
#                                                        {
#                                                             "offset": 871,
#                                                             "length": 8
#                                                        }
#                                                   ],
#                                                   "confidence": 0.894,
#                                                   "source": "D(1,0.5738,5.6652,1.2150,5.6727,1.2150,5.8339,0.5743,5.8264)"
#                                              },
#                                              "Description": {
#                                                   "type": "string",
#                                                   "valueString": "Consulting Services",
#                                                   "spans": [
#                                                        {
#                                                             "offset": 903,
#                                                             "length": 19
#                                                        }
#                                                   ],
#                                                   "confidence": 0.514,
#                                                   "source": "D(1,2.3201,5.6719,3.6378,5.6719,3.6378,5.8438,2.3201,5.8438)"
#                                              },
#                                              "ProductCode": {
#                                                   "type": "string",
#                                                   "valueString": "A123",
#                                                   "spans": [
#                                                        {
#                                                             "offset": 889,
#                                                             "length": 4
#                                                        }
#                                                   ],
#                                                   "confidence": 0.879,
#                                                   "source": "D(1,1.5906,5.6772,1.9538,5.6772,1.9538,5.8245,1.5906,5.8237)"
#                                              },
#                                              "Quantity": {
#                                                   "type": "number",
#                                                   "valueNumber": 2,
#                                                   "spans": [
#                                                        {
#                                                             "offset": 932,
#                                                             "length": 1
#                                                        }
#                                                   ],
#                                                   "confidence": 0.957,
#                                                   "source": "D(1,4.5820,5.6922,4.6775,5.6844,4.6775,5.8133,4.5820,5.8211)"
#                                              },
#                                              "QuantityUnit": {
#                                                   "type": "string",
#                                                   "valueString": "hours",
#                                                   "spans": [
#                                                        {
#                                                             "offset": 943,
#                                                             "length": 5
#                                                        }
#                                                   ],
#                                                   "confidence": 0.85,
#                                                   "source": "D(1,4.8186,5.6835,5.2170,5.6844,5.2170,5.8294,4.8186,5.8285)"
#                                              },
#                                              "TaxAmount": {
#                                                   "type": "object",
#                                                   "valueObject": {
#                                                        "Amount": {
#                                                             "type": "number",
#                                                             "valueNumber": 6,
#                                                             "spans": [
#                                                                  {
#                                                                       "offset": 974,
#                                                                       "length": 5
#                                                                  }
#                                                             ],
#                                                             "confidence": 0.974,
#                                                             "source": "D(1,6.6904,5.6719,7.0764,5.6719,7.0764,5.8330,6.6904,5.8330)"
#                                                        },
#                                                        "CurrencyCode": {
#                                                             "type": "string",
#                                                             "valueString": "USD"
#                                                        }
#                                                   }
#                                              },
#                                              "TaxRate": {
#                                                   "type": "number",
#                                                   "confidence": 0.915
#                                              },
#                                              "TotalAmount": {
#                                                   "type": "object",
#                                                   "valueObject": {
#                                                        "Amount": {
#                                                             "type": "number",
#                                                             "valueNumber": 60,
#                                                             "spans": [
#                                                                  {
#                                                                       "offset": 989,
#                                                                       "length": 6
#                                                                  }
#                                                             ],
#                                                             "confidence": 0.98,
#                                                             "source": "D(1,7.4463,5.6497,7.9281,5.6647,7.9226,5.8414,7.4408,5.8264)"
#                                                        },
#                                                        "CurrencyCode": {
#                                                             "type": "string",
#                                                             "valueString": "USD"
#                                                        }
#                                                   }
#                                              },
#                                              "UnitPrice": {
#                                                   "type": "object",
#                                                   "valueObject": {
#                                                        "Amount": {
#                                                             "type": "number",
#                                                             "valueNumber": 30,
#                                                             "spans": [
#                                                                  {
#                                                                       "offset": 958,
#                                                                       "length": 6
#                                                                  }
#                                                             ],
#                                                             "confidence": 0.971,
#                                                             "source": "D(1,5.9475,5.6665,6.4207,5.6665,6.4207,5.8276,5.9475,5.8276)"
#                                                        },
#                                                        "CurrencyCode": {
#                                                             "type": "string",
#                                                             "valueString": "USD"
#                                                        }
#                                                   }
#                                              }
#                                         }
#                                    },
#                                    {
#                                         "type": "object",
#                                         "valueObject": {
#                                              "Date": {
#                                                   "type": "date",
#                                                   "valueDate": "2021-03-05",
#                                                   "spans": [
#                                                        {
#                                                             "offset": 1016,
#                                                             "length": 8
#                                                        }
#                                                   ],
#                                                   "confidence": 0.833,
#                                                   "source": "D(1,0.5748,5.9758,1.2171,5.9787,1.2171,6.1398,0.5753,6.1369)"
#                                              },
#                                              "Description": {
#                                                   "type": "string",
#                                                   "valueString": "Document Fee",
#                                                   "spans": [
#                                                        {
#                                                             "offset": 1048,
#                                                             "length": 12
#                                                        }
#                                                   ],
#                                                   "confidence": 0.52,
#                                                   "source": "D(1,2.3264,5.9695,3.3238,5.9790,3.3223,6.1381,2.3249,6.1286)"
#                                              },
#                                              "ProductCode": {
#                                                   "type": "string",
#                                                   "valueString": "B456",
#                                                   "spans": [
#                                                        {
#                                                             "offset": 1034,
#                                                             "length": 4
#                                                        }
#                                                   ],
#                                                   "confidence": 0.902,
#                                                   "source": "D(1,1.6021,5.9783,1.9528,5.9772,1.9528,6.1177,1.6021,6.1177)"
#                                              },
#                                              "Quantity": {
#                                                   "type": "number",
#                                                   "valueNumber": 3,
#                                                   "spans": [
#                                                        {
#                                                             "offset": 1070,
#                                                             "length": 1
#                                                        }
#                                                   ],
#                                                   "confidence": 0.903,
#                                                   "source": "D(1,4.5862,5.9834,4.6775,5.9834,4.6775,6.1123,4.5862,6.1123)"
#                                              },
#                                              "QuantityUnit": {
#                                                   "type": "string",
#                                                   "confidence": 0.906
#                                              },
#                                              "TaxAmount": {
#                                                   "type": "object",
#                                                   "valueObject": {
#                                                        "Amount": {
#                                                             "type": "number",
#                                                             "valueNumber": 3,
#                                                             "spans": [
#                                                                  {
#                                                                       "offset": 1107,
#                                                                       "length": 5
#                                                                  }
#                                                             ],
#                                                             "confidence": 0.957,
#                                                             "source": "D(1,6.6904,5.9614,7.0877,5.9688,7.0847,6.1299,6.6875,6.1225)"
#                                                        },
#                                                        "CurrencyCode": {
#                                                             "type": "string",
#                                                             "valueString": "USD"
#                                                        }
#                                                   }
#                                              },
#                                              "TaxRate": {
#                                                   "type": "number",
#                                                   "confidence": 0.915
#                                              },
#                                              "TotalAmount": {
#                                                   "type": "object",
#                                                   "valueObject": {
#                                                        "Amount": {
#                                                             "type": "number",
#                                                             "valueNumber": 30,
#                                                             "spans": [
#                                                                  {
#                                                                       "offset": 1122,
#                                                                       "length": 6
#                                                                  }
#                                                             ],
#                                                             "confidence": 0.963,
#                                                             "source": "D(1,7.4449,5.9713,7.9231,5.9688,7.9240,6.1327,7.4458,6.1352)"
#                                                        },
#                                                        "CurrencyCode": {
#                                                             "type": "string",
#                                                             "valueString": "USD"
#                                                        }
#                                                   }
#                                              },
#                                              "UnitPrice": {
#                                                   "type": "object",
#                                                   "valueObject": {
#                                                        "Amount": {
#                                                             "type": "number",
#                                                             "valueNumber": 10,
#                                                             "spans": [
#                                                                  {
#                                                                       "offset": 1091,
#                                                                       "length": 6
#                                                                  }
#                                                             ],
#                                                             "confidence": 0.959,
#                                                             "source": "D(1,5.9467,5.9711,6.4207,5.9688,6.4215,6.1331,5.9475,6.1354)"
#                                                        },
#                                                        "CurrencyCode": {
#                                                             "type": "string",
#                                                             "valueString": "USD"
#                                                        }
#                                                   }
#                                              }
#                                         }
#                                    },
#                                    {
#                                         "type": "object",
#                                         "valueObject": {
#                                              "Date": {
#                                                   "type": "date",
#                                                   "valueDate": "2021-03-06",
#                                                   "spans": [
#                                                        {
#                                                             "offset": 1149,
#                                                             "length": 8
#                                                        }
#                                                   ],
#                                                   "confidence": 0.882,
#                                                   "source": "D(1,0.5753,6.2681,1.2150,6.2681,1.2150,6.4292,0.5753,6.4292)"
#                                              },
#                                              "Description": {
#                                                   "type": "string",
#                                                   "valueString": "Printing Fee",
#                                                   "spans": [
#                                                        {
#                                                             "offset": 1181,
#                                                             "length": 12
#                                                        }
#                                                   ],
#                                                   "confidence": 0.595,
#                                                   "source": "D(1,2.3222,6.2627,3.1476,6.2707,3.1459,6.4517,2.3204,6.4437)"
#                                              },
#                                              "ProductCode": {
#                                                   "type": "string",
#                                                   "valueString": "C789",
#                                                   "spans": [
#                                                        {
#                                                             "offset": 1167,
#                                                             "length": 4
#                                                        }
#                                                   ],
#                                                   "confidence": 0.827,
#                                                   "source": "D(1,1.6010,6.2716,1.9528,6.2647,1.9528,6.4151,1.6010,6.4220)"
#                                              },
#                                              "Quantity": {
#                                                   "type": "number",
#                                                   "valueNumber": 10,
#                                                   "spans": [
#                                                        {
#                                                             "offset": 1203,
#                                                             "length": 2
#                                                        }
#                                                   ],
#                                                   "confidence": 0.938,
#                                                   "source": "D(1,4.4990,6.2788,4.6733,6.2788,4.6733,6.4188,4.4990,6.4163)"
#                                              },
#                                              "QuantityUnit": {
#                                                   "type": "string",
#                                                   "valueString": "pages",
#                                                   "spans": [
#                                                        {
#                                                             "offset": 1215,
#                                                             "length": 5
#                                                        }
#                                                   ],
#                                                   "confidence": 0.796,
#                                                   "source": "D(1,4.8228,6.2950,5.2295,6.2967,5.2295,6.4444,4.8228,6.4458)"
#                                              },
#                                              "TaxAmount": {
#                                                   "type": "object",
#                                                   "valueObject": {
#                                                        "Amount": {
#                                                             "type": "number",
#                                                             "valueNumber": 1,
#                                                             "spans": [
#                                                                  {
#                                                                       "offset": 1245,
#                                                                       "length": 5
#                                                                  }
#                                                             ],
#                                                             "confidence": 0.903,
#                                                             "source": "D(1,6.6946,6.2665,7.0776,6.2692,7.0764,6.4301,6.6935,6.4274)"
#                                                        },
#                                                        "CurrencyCode": {
#                                                             "type": "string",
#                                                             "valueString": "USD"
#                                                        }
#                                                   }
#                                              },
#                                              "TaxRate": {
#                                                   "type": "number",
#                                                   "confidence": 0.915
#                                              },
#                                              "TotalAmount": {
#                                                   "type": "object",
#                                                   "valueObject": {
#                                                        "Amount": {
#                                                             "type": "number",
#                                                             "valueNumber": 10,
#                                                             "spans": [
#                                                                  {
#                                                                       "offset": 1260,
#                                                                       "length": 6
#                                                                  }
#                                                             ],
#                                                             "confidence": 0.914,
#                                                             "source": "D(1,7.4445,6.2673,7.9231,6.2634,7.9244,6.4254,7.4458,6.4293)"
#                                                        },
#                                                        "CurrencyCode": {
#                                                             "type": "string",
#                                                             "valueString": "USD"
#                                                        }
#                                                   }
#                                              },
#                                              "UnitPrice": {
#                                                   "type": "object",
#                                                   "valueObject": {
#                                                        "Amount": {
#                                                             "type": "number",
#                                                             "valueNumber": 1,
#                                                             "spans": [
#                                                                  {
#                                                                       "offset": 1230,
#                                                                       "length": 5
#                                                                  }
#                                                             ],
#                                                             "confidence": 0.914,
#                                                             "source": "D(1,6.0305,6.2670,6.4254,6.2685,6.4248,6.4308,6.0299,6.4293)"
#                                                        },
#                                                        "CurrencyCode": {
#                                                             "type": "string",
#                                                             "valueString": "USD"
#                                                        }
#                                                   }
#                                              }
#                                         }
#                                    }
#                               ]
#                          },
#                          "PaymentTerm": {
#                               "type": "string",
#                               "confidence": 0.872
#                          },
#                          "PONumber": {
#                               "type": "string",
#                               "valueString": "PO-3333",
#                               "spans": [
#                                    {
#                                         "offset": 650,
#                                         "length": 7
#                                    }
#                               ],
#                               "confidence": 0.902,
#                               "source": "D(1,1.8915,4.9083,2.4841,4.9086,2.4840,5.0602,1.8914,5.0599)"
#                          },
#                          "RemittanceAddress": {
#                               "type": "string",
#                               "valueString": "123 Remit St New York, NY, 10001",
#                               "spans": [
#                                    {
#                                         "offset": 1608,
#                                         "length": 12
#                                    },
#                                    {
#                                         "offset": 1621,
#                                         "length": 19
#                                    }
#                               ],
#                               "confidence": 0.878,
#                               "source": "D(1,0.5774,9.5498,1.4454,9.5498,1.4454,9.7002,0.5774,9.7002);D(1,0.5733,9.7500,1.9989,9.7539,1.9984,9.9266,0.5728,9.9227)"
#                          },
#                          "RemittanceAddressRecipient": {
#                               "type": "string",
#                               "valueString": "Contoso Billing",
#                               "spans": [
#                                    {
#                                         "offset": 1592,
#                                         "length": 15
#                                    }
#                               ],
#                               "confidence": 0.739,
#                               "source": "D(1,0.5711,9.3441,1.5969,9.3468,1.5965,9.5186,0.5707,9.5159)"
#                          },
#                          "ServiceAddress": {
#                               "type": "string",
#                               "valueString": "123 Service St, Redmond WA, 98052",
#                               "spans": [
#                                    {
#                                         "offset": 453,
#                                         "length": 15
#                                    },
#                                    {
#                                         "offset": 469,
#                                         "length": 17
#                                    }
#                               ],
#                               "confidence": 0.902,
#                               "source": "D(1,6.2007,3.9468,7.1980,3.9539,7.1968,4.1174,6.1995,4.1103);D(1,6.1965,4.1478,7.6452,4.1493,7.6450,4.3204,6.1963,4.3189)"
#                          },
#                          "ServiceAddressRecipient": {
#                               "type": "string",
#                               "valueString": "Microsoft Services",
#                               "spans": [
#                                    {
#                                         "offset": 434,
#                                         "length": 18
#                                    }
#                               ],
#                               "confidence": 0.782,
#                               "source": "D(1,6.1965,3.7529,7.4502,3.7544,7.4500,3.9096,6.1963,3.9081)"
#                          },
#                          "ShippingAddress": {
#                               "type": "string",
#                               "valueString": "123 Ship St, Redmond WA, 98052",
#                               "spans": [
#                                    {
#                                         "offset": 385,
#                                         "length": 12
#                                    },
#                                    {
#                                         "offset": 398,
#                                         "length": 17
#                                    }
#                               ],
#                               "confidence": 0.805,
#                               "source": "D(1,3.3307,3.9485,4.1183,3.9539,4.1172,4.1235,3.3295,4.1181);D(1,3.3245,4.1489,4.7731,4.1508,4.7729,4.3185,3.3243,4.3167)"
#                          },
#                          "ShippingAddressRecipient": {
#                               "type": "string",
#                               "valueString": "Microsoft Delivery",
#                               "spans": [
#                                    {
#                                         "offset": 366,
#                                         "length": 18
#                                    }
#                               ],
#                               "confidence": 0.7,
#                               "source": "D(1,3.3225,3.7484,4.5915,3.7575,4.5903,3.9309,3.3212,3.9218)"
#                          },
#                          "SubtotalAmount": {
#                               "type": "object",
#                               "valueObject": {
#                                    "Amount": {
#                                         "type": "number",
#                                         "valueNumber": 100
#                                    },
#                                    "CurrencyCode": {
#                                         "type": "string",
#                                         "valueString": "USD"
#                                    }
#                               }
#                          },
#                          "TaxDetails": {
#                               "type": "array",
#                               "valueArray": [
#                                    {
#                                         "type": "object",
#                                         "valueObject": {
#                                              "Amount": {
#                                                   "type": "object",
#                                                   "valueObject": {
#                                                        "Amount": {
#                                                             "type": "number",
#                                                             "valueNumber": 10,
#                                                             "spans": [
#                                                                  {
#                                                                       "offset": 1371,
#                                                                       "length": 6
#                                                                  }
#                                                             ],
#                                                             "confidence": 0.903,
#                                                             "source": "D(1,7.4500,7.1580,7.9278,7.1597,7.9272,7.3229,7.4494,7.3212)"
#                                                        },
#                                                        "CurrencyCode": {
#                                                             "type": "string",
#                                                             "valueString": "USD"
#                                                        }
#                                                   }
#                                              },
#                                              "Description": {
#                                                   "type": "string",
#                                                   "valueString": "SALES TAX",
#                                                   "spans": [
#                                                        {
#                                                             "offset": 1352,
#                                                             "length": 9
#                                                        }
#                                                   ],
#                                                   "confidence": 0.325,
#                                                   "source": "D(1,6.0181,7.1865,6.7402,7.1865,6.7402,7.3369,6.0181,7.3369)"
#                                              },
#                                              "NetAmount": {
#                                                   "type": "object",
#                                                   "valueObject": {
#                                                        "Amount": {
#                                                             "type": "number",
#                                                             "valueNumber": 100,
#                                                             "spans": [
#                                                                  {
#                                                                       "offset": 1324,
#                                                                       "length": 7
#                                                                  }
#                                                             ],
#                                                             "confidence": 0.456,
#                                                             "source": "D(1,7.3650,6.8583,7.9272,6.8519,7.9291,7.0155,7.3669,7.0220)"
#                                                        },
#                                                        "CurrencyCode": {
#                                                             "type": "string",
#                                                             "valueString": "USD"
#                                                        }
#                                                   }
#                                              },
#                                              "Rate": {
#                                                   "type": "number",
#                                                   "confidence": 0.904
#                                              }
#                                         }
#                                    }
#                               ]
#                          },
#                          "TotalAmount": {
#                               "type": "object",
# ...
#                                         },
#                                         "elements": [
#                                              "/paragraphs/44"
#                                         ]
#                                    },
#                                    {
#                                         "kind": "content",
#                                         "rowIndex": 3,
#                                         "columnIndex": 2,
#                                         "rowSpan": 1,
#                                         "columnSpan": 1,
#                                         "content": "Printing Fee",
#                                         "source": "D(1,2.253,6.1977,4.3181,6.1988,4.3187,6.4957,2.2536,6.4955)",
#                                         "span": {
#                                              "offset": 1181,
#                                              "length": 12
#                                         },
#                                         "elements": [
#                                              "/paragraphs/45"
#                                         ]
#                                    },
#                                    {
#                                         "kind": "content",
#                                         "rowIndex": 3,
#                                         "columnIndex": 3,
#                                         "rowSpan": 1,
#                                         "columnSpan": 1,
#                                         "content": "10",
#                                         "source": "D(1,4.3181,6.1988,4.7477,6.1984,4.7486,6.4957,4.3187,6.4957)",
#                                         "span": {
#                                              "offset": 1203,
#                                              "length": 2
#                                         },
#                                         "elements": [
#                                              "/paragraphs/46"
#                                         ]
#                                    },
#                                    {
#                                         "kind": "content",
#                                         "rowIndex": 3,
#                                         "columnIndex": 4,
#                                         "rowSpan": 1,
#                                         "columnSpan": 1,
#                                         "content": "pages",
#                                         "source": "D(1,4.7477,6.1984,5.5659,6.1991,5.5668,6.4962,4.7486,6.4957)",
#                                         "span": {
#                                              "offset": 1215,
#                                              "length": 5
#                                         },
#                                         "elements": [
#                                              "/paragraphs/47"
#                                         ]
#                                    },
#                                    {
#                                         "kind": "content",
#                                         "rowIndex": 3,
#                                         "columnIndex": 5,
#                                         "rowSpan": 1,
#                                         "columnSpan": 1,
#                                         "content": "$1.00",
#                                         "source": "D(1,5.5659,6.1991,6.5001,6.1998,6.5008,6.4962,5.5668,6.4962)",
#                                         "span": {
#                                              "offset": 1230,
#                                              "length": 5
#                                         },
#                                         "elements": [
#                                              "/paragraphs/48"
#                                         ]
#                                    },
#                                    {
#                                         "kind": "content",
#                                         "rowIndex": 3,
#                                         "columnIndex": 6,
#                                         "rowSpan": 1,
#                                         "columnSpan": 1,
#                                         "content": "$1.00",
#                                         "source": "D(1,6.5001,6.1998,7.1882,6.2,7.1894,6.4965,6.5008,6.4962)",
#                                         "span": {
#                                              "offset": 1245,
#                                              "length": 5
#                                         },
#                                         "elements": [
#                                              "/paragraphs/49"
#                                         ]
#                                    },
#                                    {
#                                         "kind": "content",
#                                         "rowIndex": 3,
#                                         "columnIndex": 7,
#                                         "rowSpan": 1,
#                                         "columnSpan": 1,
#                                         "content": "$10.00",
#                                         "source": "D(1,7.1882,6.2,8.0088,6.2014,8.0092,6.4973,7.1894,6.4965)",
#                                         "span": {
#                                              "offset": 1260,
#                                              "length": 6
#                                         },
#                                         "elements": [
#                                              "/paragraphs/50"
#                                         ]
#                                    }
#                               ],
#                               "source": "D(1,0.5006,5.3093,8.0103,5.304,8.0103,6.5098,0.5006,6.5044)",
#                               "span": {
#                                    "offset": 720,
#                                    "length": 566
#                               }
#                          },
#                          {
#                               "rowCount": 5,
#                               "columnCount": 2,
#                               "cells": [
#                                    {
#                                         "kind": "columnHeader",
#                                         "rowIndex": 0,
#                                         "columnIndex": 0,
#                                         "rowSpan": 1,
#                                         "columnSpan": 1,
#                                         "content": "SUBTOTAL",
#                                         "source": "D(1,4.7526,6.7986,6.8123,6.7979,6.8124,7.0911,4.7524,7.0913)",
#                                         "span": {
#                                              "offset": 1306,
#                                              "length": 8
#                                         },
#                                         "elements": [
#                                              "/paragraphs/51"
#                                         ]
#                                    },
#                                    {
#                                         "kind": "content",
#                                         "rowIndex": 0,
#                                         "columnIndex": 1,
#                                         "rowSpan": 1,
#                                         "columnSpan": 1,
#                                         "content": "$100.00",
#                                         "source": "D(1,6.8123,6.7979,7.9965,6.7977,7.9976,7.0916,6.8124,7.0911)",
#                                         "span": {
#                                              "offset": 1324,
#                                              "length": 7
#                                         },
#                                         "elements": [
#                                              "/paragraphs/52"
#                                         ]
#                                    },
#                                    {
#                                         "kind": "columnHeader",
#                                         "rowIndex": 1,
#                                         "columnIndex": 0,
#                                         "rowSpan": 1,
#                                         "columnSpan": 1,
#                                         "content": "SALES TAX",
#                                         "source": "D(1,4.7524,7.0913,6.8124,7.0911,6.8131,7.3912,4.7518,7.3924)",
#                                         "span": {
#                                              "offset": 1352,
#                                              "length": 9
#                                         },
#                                         "elements": [
#                                              "/paragraphs/53"
#                                         ]
#                                    },
#                                    {
#                                         "kind": "content",
#                                         "rowIndex": 1,
#                                         "columnIndex": 1,
#                                         "rowSpan": 1,
#                                         "columnSpan": 1,
#                                         "content": "$10.00",
#                                         "source": "D(1,6.8124,7.0911,7.9976,7.0916,7.9986,7.3911,6.8131,7.3912)",
#                                         "span": {
#                                              "offset": 1371,
#                                              "length": 6
#                                         },
#                                         "elements": [
#                                              "/paragraphs/54"
#                                         ]
#                                    },
#                                    {
#                                         "kind": "columnHeader",
#                                         "rowIndex": 2,
#                                         "columnIndex": 0,
#                                         "rowSpan": 1,
#                                         "columnSpan": 1,
#                                         "content": "TOTAL",
#                                         "source": "D(1,4.7518,7.3924,6.8131,7.3912,6.8131,7.6929,4.7514,7.6935)",
#                                         "span": {
#                                              "offset": 1398,
#                                              "length": 5
#                                         },
#                                         "elements": [
#                                              "/paragraphs/55"
#                                         ]
#                                    },
#                                    {
#                                         "kind": "content",
#                                         "rowIndex": 2,
#                                         "columnIndex": 1,
#                                         "rowSpan": 1,
#                                         "columnSpan": 1,
#                                         "content": "$110.00",
#                                         "source": "D(1,6.8131,7.3912,7.9986,7.3911,7.9997,7.6929,6.8131,7.6929)",
#                                         "span": {
#                                              "offset": 1413,
#                                              "length": 7
#                                         },
#                                         "elements": [
#                                              "/paragraphs/56"
#                                         ]
#                                    },
#                                    {
#                                         "kind": "columnHeader",
#                                         "rowIndex": 3,
#                                         "columnIndex": 0,
#                                         "rowSpan": 1,
#                                         "columnSpan": 1,
#                                         "content": "PREVIOUS UNPAID BALANCE",
#                                         "source": "D(1,4.7514,7.6935,6.8131,7.6929,6.8131,7.9844,4.751,7.9848)",
#                                         "span": {
#                                              "offset": 1441,
#                                              "length": 23
#                                         },
#                                         "elements": [
#                                              "/paragraphs/57"
#                                         ]
#                                    },
#                                    {
#                                         "kind": "content",
#                                         "rowIndex": 3,
#                                         "columnIndex": 1,
#                                         "rowSpan": 1,
#                                         "columnSpan": 1,
#                                         "content": "$500.00",
#                                         "source": "D(1,6.8131,7.6929,7.9997,7.6929,8.0008,7.9847,6.8131,7.9844)",
#                                         "span": {
#                                              "offset": 1474,
#                                              "length": 7
#                                         },
#                                         "elements": [
#                                              "/paragraphs/58"
#                                         ]
#                                    },
#                                    {
#                                         "kind": "columnHeader",
#                                         "rowIndex": 4,
#                                         "columnIndex": 0,
#                                         "rowSpan": 1,
#                                         "columnSpan": 1,
#                                         "content": "AMOUNT DUE",
#                                         "source": "D(1,4.751,7.9848,6.8131,7.9844,6.8148,8.2845,4.7508,8.2843)",
#                                         "span": {
#                                              "offset": 1502,
#                                              "length": 10
#                                         },
#                                         "elements": [
#                                              "/paragraphs/59"
#                                         ]
#                                    },
#                                    {
#                                         "kind": "content",
#                                         "rowIndex": 4,
#                                         "columnIndex": 1,
#                                         "rowSpan": 1,
#                                         "columnSpan": 1,
#                                         "content": "$610.00",
#                                         "source": "D(1,6.8131,7.9844,8.0008,7.9847,8.002,8.2842,6.8148,8.2845)",
#                                         "span": {
#                                              "offset": 1522,
#                                              "length": 7
#                                         },
#                                         "elements": [
#                                              "/paragraphs/60"
#                                         ]
#                                    }
#                               ],
#                               "source": "D(1,4.7729,6.7944,8.0061,6.7837,8.0061,8.2715,4.7729,8.2769)",
#                               "span": {
#                                    "offset": 1289,
#                                    "length": 260
#                               }
#                          }
#                     ],
#                     "analyzerId": "prebuilt-invoice",
#                     "mimeType": "application/pdf"
#                }
#           ]
#      },
#      "usage": {
#           "documentPagesStandard": 1,
#           "contextualizationTokens": 1000,
#           "tokens": {
#                "gpt-4.1-input": 14535,
#                "gpt-4.1-output": 1641,
#                "text-embedding-3-large": 672
#           }
#      }
# }

# %%
saved_file_path = save_json_to_file(analysis_result, filename_prefix="prebuilt_invoice_result")
# Out:
# 💾 Analysis result saved to: results/prebuilt_invoice_result_20260211_133147.json

# %%
# !ls $saved_file_path -lh
# Out:
# -rwxrwxrwx 1 root root 153K Feb 11 13:31 results/prebuilt_invoice_result_20260211_133147.json
